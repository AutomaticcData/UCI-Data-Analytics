# %% [markdown]
# ## WeatherPy - Aalvarez

# %%
#Created on Sun Sep 4 07:12 2018
#@author: anthonyalvarez
#Test Files: WeatheyPy_00.ipynb - WeatheyPy_03.ipynb

# %% [markdown]
# ### Referenced Material
#  * https://bootcampspot-v2.com/sessions/472909/videos/25279
#  * http://pandas.pydata.org/pandas-docs/version/0.17/generated/pandas.DataFrame.set_value.html
#  * https://stackoverflow.com/questions/5244810/python-appending-a-dictionary-to-a-list-i-see-a-pointer-like-behavior
#  * https://stackoverflow.com/questions/5242933/what-was-the-motivation-for-doing-lists-augmented-assignment-in-place-in-py
#  * https://stackoverflow.com/questions/4432208/how-does-work-in-python
#  * https://python-reference.readthedocs.io/en/latest/docs/operators/modulus.html
#  * https://stackoverflow.com/questions/43668827/python-modulo-function
#  * https://stackoverflow.com/questions/44513738/pandas-create-empty-dataframe-with-only-column-names
#  * https://www.tutorialspoint.com/python/string_title.htm
#  * https://stackoverflow.com/questions/134934/display-number-with-leading-zeros
#  * https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.to_csv.html
#  * https://matplotlib.org/examples/color/colormaps_reference.html
#  * dates from the openweatherapi are stored as [dt] Time of data calculation, unix, UTC
#  * https://openweathermap.org/current
#  * https://stackoverflow.com/questions/46565580/convert-unix-timestamp-in-python-to-datetime-and-make-2-hours-behind
#  * https://stackoverflow.com/questions/9622163/save-plot-to-image-file-instead-of-displaying-it-using-matplotlib

# %% [markdown]
# ## Requirements
#
# In this example, you'll be creating a Python script to visualize the weather of 500+ cities across the world of varying distance from the equator. To accomplish this, you'll be utilizing a [simple Python library](https://pypi.python.org/pypi/citipy), the [OpenWeatherMap API](https://openweathermap.org/api), and a little common sense to create a representative model of weather across world cities.
#
# Your objective is to build a series of scatter plots to showcase the following relationships:
#
# * Temperature (F) vs. Latitude
# * Humidity (%) vs. Latitude
# * Cloudiness (%) vs. Latitude
# * Wind Speed (mph) vs. Latitude
#
# Your final notebook must:
#
# * Randomly select **at least** 500 unique (non-repeat) cities based on latitude and longitude.
# * Perform a weather check on each of the cities using a series of successive API calls.
# * Include a print log of each city as it's being processed with the city number and city name.
# * Save both a CSV of all data retrieved and png images for each scatter plot.

# %% [markdown]
# ---
# ### Data Sources ![Data Sources Used](images/owm_01.png "OpenWeather")
#
# * [OpenWeather](https://openweathermap.org/api) Clinical Data including Time, Size and Metastatic Sites

# %% [markdown]
# ---
# ### Data Visualizations
#
# <a href="images/latitude_vs_temperature_01.png" target="_blank">Latitude Vs. Temperature (F)</a>
# <img src="images/latitude_vs_temperature_01.png" alt="Lat V Temp" height="600" width="400">
#
# <a href="images/latitude_vs_humidity_02.png" target="_blank">Latitude Vs. Humidity (%)</a>
# <img src="images/latitude_vs_humidity_02.png" alt="Lat V Humidity" height="600" width="400">
#
# <a href="images/latitude_vs_clouds_03.png" target="_blank">Latitude Vs. Cloudiness (%)</a>
# <img src="images/latitude_vs_clouds_03.png" alt="Lat V Clouds" height="600" width="400">
#
# <a href="images/latitude_vs_winds_04.png" target="_blank">Latitude Vs. Wind Speed (MPH)</a>
# <img src="images/latitude_vs_winds_04.png" alt="Lat V Wind" height="600" width="400">

# %% [markdown]
# ---
# ### Data Output ![Data Sources Used](images/excelcsv.png "Excel Csv")
# * [Output Data](data/city_weather.csv) Output data from API used for visualizations

# %% [markdown]
# ---
# ### Observable Trends
#
#  * Rather than just state the obvious "It gets hotter as you approach the equator", with the data analysed below we further prove it by visualizing the max temperatures from random cities
#
#
#  * asdfasdfasdfsadfasfd
#
#
#  * asdfasdfasdfasdf

# %% [markdown]
# ---
# ## Dependencies

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

from datetime import datetime, timedelta

# Import API key
from config import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ---
# ## Functions

# %%
#function for time conversion
#https://stackoverflow.com/questions/46565580/convert-unix-timestamp-in-python-to-datetime-and-make-2-hours-behind
def unixtodate(unix_ts):
    #unix_ts = 1507126064
    dt = (datetime.fromtimestamp(unix_ts) - timedelta(hours=2)).strftime('%Y-%m-%d %H:%M:%S')
    return dt

#created this to append the date to the file name later on
def datatofile(filepath, filename, texttoadd, fileext):
    output_file = filepath + filename + "_" + texttoadd + fileext
    return output_file

# %% [markdown]
# ---
# ## File Operations

# %%
#image path
image_path = "images/"
image_name = ""
image_date = ""
image_extension = ".png"

# Output File (CSV)
file_path = "data/"
file_name = "city_weather"
file_date = ""
file_extension = ".csv"

# %% [markdown]
# ---
# ## Functional Logic

# %%
# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# List for holding lat_lngs and cities
lat_lngs = []
cities = []

#add a list to view cities found nearby
citiesnearby = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)

#join the data for a workable use variable
lat_lngs = zip(lats, lngs)

# %%
#using the code to build a dataframe for lat/long visaid
#maybe create a dataframe with empty columns and then add to it?
#https://stackoverflow.com/questions/44513738/pandas-create-empty-dataframe-with-only-column-names

#bad syntax missing {}
#latlong_df = pd.DataFrame("Lat": lats, "Long": lngs)
latlong_df = pd.DataFrame({"Lat": lats, "Long": lngs})

#verify data
latlong_df.head()
# Out:
#          Lat        Long
# 0 -13.546866  152.323796
# 1   8.172401 -102.291026
# 2   4.094776  104.236239
# 3  20.341151  -15.900884
# 4 -65.926657  148.901955

# %%
# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    #find the total amount of cities nearby because im curious
    citiesnearby.append(city)
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        #print(city)
        cities.append(city)

# Print the city count to confirm sufficient count
#print(len(cities))
#print(len(citiesnearby))

num_cities_found = len(cities)
num_coordinates = len(citiesnearby)

print(f'Using {num_coordinates} coordinates, found {num_cities_found} citie(s)')
# Out:
# Using 1500 coordinates, found 631 citie(s)

# %%
#view the collected output
cities_df = pd.DataFrame({"Cities":cities})
cities_df.head()
# Out:
#        Cities
# 0     samarai
# 1    acapulco
# 2       cukai
# 3  nouadhibou
# 4      hobart

# %%
#configure the base url to be used
baseurl = "http://api.openweathermap.org/data/2.5/weather?"

#we dont want celsius
#units = "metric"

#we do want to use farenheit
units = "imperial"

# Build partial query URL
query_url = f"{baseurl}appid={api_key}&units={units}&q="

#print to view/verify our working url
#print(query_url)

# %% [markdown]
# ---
# ### Main Data Fetch

# %%
#used for testing only --------->
#track the unique responses, found 2 [200, 404]
#responsetypes = [] 
#<-------------------------------

#set up a counter
counter = 0

#set up a variable to break a certain # of times out of the loop(for testing)
numbreak = 15

#count cities added
citiesadded = 0

#set up a grouping or modulus group using %
modnum = 50

#set the counter for the group starting at Group 1
modgroup = 1

#use a dictionary object to capture info
#weathercities = {"city":,"country":}

#PROBLEMS!!! = [(face2desk)for problem in pythonproblems] :)

#dictionary object not working using list instead
weathercities = []


print('-----------------------------')
print(f'Begin Processing from {len(cities)} Cities. {numbreak} Attempts')
print('-----------------------------')


#loop through the dataframe
for index, row in cities_df.iterrows():
    
    #grab the city into a variable
    #print(row["Cities"])
    thecity = row["Cities"]
    
    #add the city into the base url 
    city_url = query_url + thecity
    #print(city_url)
    
    #get data from the api call
    city_response = requests.get(city_url).json()
        

    ##This section for testing only ---------->
    ##checking for bad responses, only check to see if its possible to get have errors
    ##results are we found 2 different response types so we have to deal with them
    #responsetype = requests.get(city_url).status_code
    #if responsetype not in responsetypes:
    #    responsetypes.append(responsetype)
    ##<-----------------End testing reponse types
    
    #testing mod groups
    #if (index % 2 == 0):
        #modgroup +=1
    #<----end mod testing
        
    
    
    #if we find a response with 404 we need to skip it
    responsetype = requests.get(city_url).status_code
    #print(responsetype)
    
    #really only care about a good response
    if responsetype == 200:
        citiesadded += 1
        #print(responsetype)
        #print(city_response["id"])
        #print(city_response["sys"]["country"])
        city_id = city_response["id"]
        city_country = city_response["sys"]["country"]
        city_lat = city_response["coord"]["lon"]
        city_long = city_response["coord"]["lat"]
        city_name = city_response["name"]
        city_temp_max = city_response["main"]["temp_max"]
        city_humidity = city_response["main"]["humidity"]
        city_clouds = city_response["clouds"]["all"]
        city_winds = city_response["wind"]["speed"]
        
        #use function to convert unix to datetime
        city_analysis_date = unixtodate(city_response["dt"])
        
        #make it so that the cities added Groupings are ONLY for cities added, 
        #and NOT for the entire list we are searching, this would give us inconsistencies in groups
        if (citiesadded % modnum ==0):
            modgroup +=1
        
        #print(f'ID:{city_id} Country:{city_country} City:{city_name}')
        
        #adding date of analysis
        weathercities.append({"cityid":city_id
                              ,"country":city_country
                              ,"city":city_name
                              ,"lat":city_lat
                              ,"long":city_long
                              ,"max temp":city_temp_max
                              ,"humidity":city_humidity
                              ,"cloudiness":city_clouds
                              ,"wind speed":city_winds
                              ,"groupingid":modgroup
                              ,"analysis date":city_analysis_date
                             })

        #print(f'Adding {counter} city{city_name} ModGroup# {modgroup}')
        #"{:10.4f}".format(x)
        #https://stackoverflow.com/questions/134934/display-number-with-leading-zeros
        print(f'{str(index).zfill(2)}: Add  {citiesadded} City: {thecity.title()} Group {modgroup}')
        
    else:
        #print(f'City:{thecity} Response:{responsetype}')
        print(f'{str(index).zfill(2)}: Skip ** City:{thecity.title()} not found.')
    
    #print(f'ModGroup# {modgroup}')
    
    
    #Begin testing break------>
    #testing for the first 5 records
    #if counter == numbreak:
    #    break
    #<-----------end testing
      
    #increment the counter
    counter+=1
        

  
    #display a final output of status
print('-----------------------------')
print('Data Retrieval Complete      \n')
# Out:
# -----------------------------
# Begin Processing from 631 Cities. 15 Attempts
# -----------------------------
# 00: Add  1 City: Samarai Group 1
# 01: Add  2 City: Acapulco Group 1
# 02: Add  3 City: Cukai Group 1
# 03: Add  4 City: Nouadhibou Group 1
# 04: Add  5 City: Hobart Group 1
# 05: Add  6 City: Punta Arenas Group 1
# 06: Add  7 City: Porto Walter Group 1
# 07: Add  8 City: Hermanus Group 1
# 08: Add  9 City: Mataura Group 1
# 09: Add  10 City: Georgetown Group 1
# 10: Add  11 City: Kodiak Group 1
# 11: Add  12 City: Saint-Georges Group 1
# 12: Add  13 City: Ushuaia Group 1
# 13: Add  14 City: Kadoma Group 1
# 14: Add  15 City: Dikson Group 1
# 15: Add  16 City: Lebu Group 1
# 16: Skip ** City:Belushya Guba not found.
# 17: Add  17 City: Bowen Group 1
# 18: Add  18 City: Alofi Group 1
# 19: Add  19 City: Garhi Khairo Group 1
# 20: Add  20 City: Yellowknife Group 1
# 21: Add  21 City: Tuktoyaktuk Group 1
# 22: Add  22 City: Khatanga Group 1
# 23: Add  23 City: Cape Town Group 1
# 24: Add  24 City: Sur Group 1
# 25: Add  25 City: Cherskiy Group 1
# 26: Add  26 City: Tuatapere Group 1
# 27: Add  27 City: Pochutla Group 1
# 28: Skip ** City:Bengkulu not found.
# 29: Add  28 City: Rikitea Group 1
# 30: Add  29 City: Lavrentiya Group 1
# 31: Add  30 City: Ponta Do Sol Group 1
# 32: Add  31 City: Cayhagan Group 1
# 33: Add  32 City: Avarua Group 1
# 34: Skip ** City:Chagda not found.
# 35: Add  33 City: Presidente Olegario Group 1
# 36: Add  34 City: Gamba Group 1
# 37: Skip ** City:Illoqqortoormiut not found.
# 38: Add  35 City: Camacha Group 1
# 39: Skip ** City:Tsihombe not found.
# 40: Add  36 City: Phalaborwa Group 1
# 41: Add  37 City: Saint-Philippe Group 1
# 42: Add  38 City: Busselton Group 1
# 43: Add  39 City: Jalu Group 1
# 44: Add  40 City: Sao Filipe Group 1
# 45: Add  41 City: Jamestown Group 1
# 46: Add  42 City: Bull Savanna Group 1
# 47: Skip ** City:Sentyabrskiy not found.
# 48: Add  43 City: Cascais Group 1
# 49: Add  44 City: Kruisfontein Group 1
# 50: Add  45 City: Bluff Group 1
# 51: Add  46 City: Dingle Group 1
# 52: Add  47 City: Paamiut Group 1
# 53: Add  48 City: Esperance Group 1
# 54: Add  49 City: Hilo Group 1
# 55: Add  50 City: Kavieng Group 2
# 56: Skip ** City:Toliary not found.
# 57: Add  51 City: Hofn Group 2
# 58: Add  52 City: Pangnirtung Group 2
# 59: Add  53 City: Xinxiang Group 2
# 60: Add  54 City: Atuona Group 2
# 61: Add  55 City: Lahaina Group 2
# 62: Add  56 City: Mar Del Plata Group 2
# 63: Add  57 City: Wajima Group 2
# 64: Add  58 City: Magsaysay Group 2
# 65: Add  59 City: Tarut Group 2
# 66: Add  60 City: Karratha Group 2
# 67: Add  61 City: Bose Group 2
# 68: Add  62 City: Portland Group 2
# 69: Add  63 City: Lazaro Cardenas Group 2
# 70: Skip ** City:Taolanaro not found.
# 71: Add  64 City: Calvinia Group 2
# 72: Add  65 City: Vaini Group 2
# 73: Skip ** City:Korla not found.
# 74: Add  66 City: Kapaa Group 2
# 75: Add  67 City: Rio Claro Group 2
# 76: Add  68 City: Mattawa Group 2
# 77: Add  69 City: Varhaug Group 2
# 78: Add  70 City: Butaritari Group 2
# 79: Add  71 City: Albany Group 2
# 80: Add  72 City: Arraial Do Cabo Group 2
# 81: Skip ** City:Tlahualilo not found.
# 82: Add  73 City: Lowell Group 2
# 83: Add  74 City: Keflavik Group 2
# 84: Add  75 City: La Cruz Group 2
# 85: Add  76 City: Rorvik Group 2
# 86: Add  77 City: Awbari Group 2
# 87: Add  78 City: Mao Group 2
# 88: Add  79 City: Pervomayskiy Group 2
# 89: Add  80 City: Nyurba Group 2
# 90: Add  81 City: Isangel Group 2
# 91: Add  82 City: Maceio Group 2
# 92: Add  83 City: Luderitz Group 2
# 93: Add  84 City: Vostok Group 2
# 94: Add  85 City: Bathsheba Group 2
# 95: Add  86 City: Rivadavia Group 2
# 96: Add  87 City: Visnes Group 2
# 97: Add  88 City: Turukhansk Group 2
# 98: Add  89 City: Cidreira Group 2
# 99: Add  90 City: Yumen Group 2
# 100: Add  91 City: Richards Bay Group 2
# 101: Add  92 City: Katsuura Group 2
# 102: Add  93 City: Boa Vista Group 2
# 103: Add  94 City: Victoria Group 2
# 104: Add  95 City: San Carlos De Bariloche Group 2
# 105: Add  96 City: Garni Group 2
# 106: Add  97 City: New Norfolk Group 2
# 107: Skip ** City:Rungata not found.
# 108: Add  98 City: Yulara Group 2
# 109: Add  99 City: Ribeira Grande Group 2
# 110: Skip ** City:Bardiyah not found.
# 111: Add  100 City: Sabha Group 3
# 112: Add  101 City: Road Town Group 3
# 113: Add  102 City: Gisborne Group 3
# 114: Add  103 City: Linxia Group 3
# 115: Skip ** City:Grand River South East not found.
# 116: Add  104 City: Bocaiuva Group 3
# 117: Add  105 City: San Rafael Group 3
# 118: Add  106 City: Cairns Group 3
# 119: Add  107 City: Port Elizabeth Group 3
# 120: Add  108 City: Khash Group 3
# 121: Skip ** City:Barentsburg not found.
# 122: Add  109 City: Saskylakh Group 3
# 123: Skip ** City:Hlotse not found.
# 124: Add  110 City: Jijiga Group 3
# 125: Add  111 City: Maniitsoq Group 3
# 126: Add  112 City: Leningradskiy Group 3
# 127: Add  113 City: Longyearbyen Group 3
# 128: Add  114 City: Dangriga Group 3
# 129: Add  115 City: Vila Velha Group 3
# 130: Add  116 City: Sungaipenuh Group 3
# 131: Add  117 City: Vicosa Group 3
# 132: Add  118 City: Komsomolskiy Group 3
# 133: Add  119 City: San Jeronimo Group 3
# 134: Add  120 City: Kununurra Group 3
# 135: Add  121 City: Puruandiro Group 3
# 136: Add  122 City: Cockburn Town Group 3
# 137: Add  123 City: Deputatskiy Group 3
# 138: Add  124 City: Lyubim Group 3
# 139: Add  125 City: Torbay Group 3
# 140: Add  126 City: Koslan Group 3
# 141: Add  127 City: Conceicao Do Araguaia Group 3
# 142: Add  128 City: Derzhavinsk Group 3
# 143: Add  129 City: Geraldton Group 3
# 144: Add  130 City: Mahebourg Group 3
# 145: Add  131 City: Bandarbeyla Group 3
# 146: Add  132 City: Japura Group 3
# 147: Add  133 City: Pemba Group 3
# 148: Add  134 City: Tsabong Group 3
# 149: Add  135 City: Ordynskoye Group 3
# 150: Add  136 City: Magaramkent Group 3
# 151: Add  137 City: Aitape Group 3
# 152: Add  138 City: Padang Group 3
# 153: Add  139 City: Nantucket Group 3
# 154: Skip ** City:Mergui not found.
# 155: Add  140 City: Rincon Group 3
# 156: Add  141 City: Puerto Ayora Group 3
# 157: Add  142 City: Sola Group 3
# 158: Add  143 City: Ishigaki Group 3
# 159: Add  144 City: Lorengau Group 3
# 160: Add  145 City: Vestmannaeyjar Group 3
# 161: Add  146 City: Abonnema Group 3
# 162: Add  147 City: Chingirlau Group 3
# 163: Add  148 City: Barrow Group 3
# 164: Add  149 City: Viedma Group 3
# 165: Add  150 City: Nuuk Group 4
# 166: Add  151 City: Tasiilaq Group 4
# 167: Add  152 City: Castro Group 4
# 168: Add  153 City: East London Group 4
# 169: Add  154 City: San Cristobal Group 4
# 170: Add  155 City: Iqaluit Group 4
# 171: Add  156 City: Mezen Group 4
# 172: Add  157 City: Kytmanovo Group 4
# 173: Add  158 City: Fukue Group 4
# 174: Add  159 City: Kulhudhuffushi Group 4
# 175: Add  160 City: Qaanaaq Group 4
# 176: Add  161 City: Luzhou Group 4
# 177: Add  162 City: Mufumbwe Group 4
# 178: Add  163 City: Kogon Group 4
# 179: Add  164 City: Upernavik Group 4
# 180: Add  165 City: Esso Group 4
# 181: Add  166 City: Beloha Group 4
# 182: Add  167 City: San Jose Del Guaviare Group 4
# 183: Add  168 City: High Level Group 4
# 184: Add  169 City: Meulaboh Group 4
# 185: Add  170 City: Tiksi Group 4
# 186: Add  171 City: Manakara Group 4
# 187: Skip ** City:Maloshuyka not found.
# 188: Add  172 City: Kaiyuan Group 4
# 189: Add  173 City: Tabou Group 4
# 190: Add  174 City: Marsa Matruh Group 4
# 191: Add  175 City: Lufilufi Group 4
# 192: Add  176 City: Port Augusta Group 4
# 193: Add  177 City: Sioux Lookout Group 4
# 194: Add  178 City: Borogontsy Group 4
# 195: Add  179 City: Minab Group 4
# 196: Add  180 City: Barcelos Group 4
# 197: Skip ** City:Tasbuget not found.
# 198: Add  181 City: Ostrovnoy Group 4
# 199: Add  182 City: Tilichiki Group 4
# 200: Add  183 City: Bethel Group 4
# 201: Add  184 City: Beni Mazar Group 4
# 202: Add  185 City: Cabo San Lucas Group 4
# 203: Add  186 City: Karlovac Group 4
# 204: Add  187 City: Nizhniy Kuranakh Group 4
# 205: Add  188 City: North Platte Group 4
# 206: Add  189 City: Hithadhoo Group 4
# 207: Add  190 City: Boralday Group 4
# 208: Add  191 City: Santa Cruz Group 4
# 209: Add  192 City: Bahia Honda Group 4
# 210: Add  193 City: Rafai Group 4
# 211: Add  194 City: Patterson Group 4
# 212: Add  195 City: Thompson Group 4
# 213: Add  196 City: Sechura Group 4
# 214: Add  197 City: Ulladulla Group 4
# 215: Add  198 City: Klichka Group 4
# 216: Add  199 City: Kyren Group 4
# 217: Add  200 City: Caborca Group 5
# 218: Add  201 City: Souillac Group 5
# 219: Add  202 City: San Policarpo Group 5
# 220: Add  203 City: Pisco Group 5
# 221: Add  204 City: Narsaq Group 5
# 222: Add  205 City: Brigantine Group 5
# 223: Add  206 City: Hasaki Group 5
# 224: Add  207 City: Mitsamiouli Group 5
# 225: Add  208 City: Prachuap Khiri Khan Group 5
# 226: Add  209 City: Smidovich Group 5
# 227: Add  210 City: Ancud Group 5
# 228: Add  211 City: Ajaccio Group 5
# 229: Add  212 City: Salo Group 5
# 230: Add  213 City: Haines Junction Group 5
# 231: Add  214 City: Atar Group 5
# 232: Add  215 City: Kaitangata Group 5
# 233: Skip ** City:Attawapiskat not found.
# 234: Add  216 City: Nome Group 5
# 235: Add  217 City: Talcahuano Group 5
# 236: Add  218 City: Chuy Group 5
# 237: Add  219 City: Lingao Group 5
# 238: Add  220 City: Palmer Group 5
# 239: Skip ** City:Olafsvik not found.
# 240: Add  221 City: Mana Group 5
# 241: Add  222 City: Port Alfred Group 5
# 242: Add  223 City: Nikolskoye Group 5
# 243: Add  224 City: Berezovyy Group 5
# 244: Add  225 City: Miro Khan Group 5
# 245: Add  226 City: Clyde River Group 5
# 246: Add  227 City: Priiskovyy Group 5
# 247: Add  228 City: Redmond Group 5
# 248: Add  229 City: Carnarvon Group 5
# 249: Add  230 City: Port Lincoln Group 5
# 250: Add  231 City: San Patricio Group 5
# 251: Add  232 City: Chokurdakh Group 5
# 252: Add  233 City: Yerbogachen Group 5
# 253: Add  234 City: Malanje Group 5
# 254: Add  235 City: Sterlitamak Group 5
# 255: Add  236 City: Mount Isa Group 5
# 256: Add  237 City: Pilot Butte Group 5
# 257: Add  238 City: Haradok Group 5
# 258: Add  239 City: Bilma Group 5
# 259: Add  240 City: Saint-Pierre Group 5
# 260: Skip ** City:Balimo not found.
# 261: Add  241 City: Labytnangi Group 5
# 262: Add  242 City: Luxor Group 5
# 263: Add  243 City: Wanning Group 5
# 264: Add  244 City: Dzilam Gonzalez Group 5
# 265: Skip ** City:Saleaula not found.
# 266: Add  245 City: Anadyr Group 5
# 267: Add  246 City: Dinguiraye Group 5
# 268: Add  247 City: Caluquembe Group 5
# 269: Skip ** City:Marcona not found.
# 270: Add  248 City: Evanston Group 5
# 271: Add  249 City: Nouakchott Group 5
# 272: Add  250 City: Balkanabat Group 6
# 273: Add  251 City: Tabuk Group 6
# 274: Add  252 City: Urengoy Group 6
# 275: Skip ** City:Westpunt not found.
# 276: Add  253 City: Poum Group 6
# 277: Add  254 City: La Romana Group 6
# 278: Add  255 City: Norman Wells Group 6
# 279: Add  256 City: Hamilton Group 6
# 280: Add  257 City: Vangaindrano Group 6
# 281: Add  258 City: Sangin Group 6
# 282: Add  259 City: Touros Group 6
# 283: Add  260 City: Manggar Group 6
# 284: Add  261 City: Saldanha Group 6
# 285: Add  262 City: Arlit Group 6
# 286: Skip ** City:Grimari not found.
# 287: Add  263 City: Guozhen Group 6
# 288: Add  264 City: Bredasdorp Group 6
# 289: Skip ** City:Tabiauea not found.
# 290: Add  265 City: Kieta Group 6
# 291: Add  266 City: Cerignola Group 6
# 292: Add  267 City: Xai-Xai Group 6
# 293: Add  268 City: Bonthe Group 6
# 294: Skip ** City:Tumannyy not found.
# 295: Add  269 City: Pyshma Group 6
# 296: Add  270 City: Krasnyy Yar Group 6
# 297: Skip ** City:Tidore not found.
# 298: Add  271 City: Vitim Group 6
# 299: Add  272 City: Shakawe Group 6
# 300: Add  273 City: Cayenne Group 6
# 301: Add  274 City: Kutum Group 6
# 302: Add  275 City: Abapo Group 6
# 303: Add  276 City: Ostersund Group 6
# 304: Add  277 City: Berlevag Group 6
# 305: Add  278 City: Antofagasta Group 6
# 306: Skip ** City:Kasra not found.
# 307: Add  279 City: Inongo Group 6
# 308: Add  280 City: Conneaut Group 6
# 309: Add  281 City: Issenye Group 6
# 310: Add  282 City: Jaciara Group 6
# 311: Add  283 City: Broome Group 6
# 312: Add  284 City: Uray Group 6
# 313: Add  285 City: Adrar Group 6
# 314: Add  286 City: Klaksvik Group 6
# 315: Add  287 City: Puerto Madryn Group 6
# 316: Add  288 City: Becal Group 6
# 317: Add  289 City: Cooma Group 6
# 318: Add  290 City: Quelimane Group 6
# 319: Add  291 City: Tessalit Group 6
# 320: Add  292 City: Oranjemund Group 6
# 321: Add  293 City: Miraflores Group 6
# 322: Add  294 City: Miles City Group 6
# 323: Add  295 City: Duku Group 6
# 324: Skip ** City:Bajo Baudo not found.
# 325: Add  296 City: Hervey Bay Group 6
# 326: Add  297 City: Okhotsk Group 6
# 327: Add  298 City: Capao Da Canoa Group 6
# 328: Add  299 City: Eureka Group 6
# 329: Skip ** City:Naftah not found.
# 330: Add  300 City: Pontianak Group 7
# 331: Add  301 City: Locri Group 7
# 332: Skip ** City:Urdzhar not found.
# 333: Add  302 City: Jacareacanga Group 7
# 334: Add  303 City: Keti Bandar Group 7
# 335: Add  304 City: Lagoa Group 7
# 336: Add  305 City: Pangody Group 7
# 337: Add  306 City: Belmonte Group 7
# 338: Add  307 City: Ust-Kulom Group 7
# 339: Add  308 City: Marystown Group 7
# 340: Add  309 City: Surenavan Group 7
# 341: Add  310 City: Avera Group 7
# 342: Add  311 City: Bharatpur Group 7
# 343: Skip ** City:Vestbygda not found.
# 344: Add  312 City: Bolanos De Calatrava Group 7
# 345: Add  313 City: Rondonopolis Group 7
# 346: Add  314 City: Sirhind Group 7
# 347: Add  315 City: Mandera Group 7
# 348: Add  316 City: Sokoni Group 7
# 349: Add  317 City: Kathu Group 7
# 350: Skip ** City:Phan Rang not found.
# 351: Add  318 City: Port Blair Group 7
# 352: Add  319 City: Batemans Bay Group 7
# 353: Add  320 City: Teguise Group 7
# 354: Skip ** City:Urumqi not found.
# 355: Add  321 City: Svetlogorsk Group 7
# 356: Add  322 City: Sinnamary Group 7
# 357: Add  323 City: Pevek Group 7
# 358: Add  324 City: Laguna Group 7
# 359: Add  325 City: Caserta Group 7
# 360: Skip ** City:Mizpe Ramon not found.
# 361: Add  326 City: College Group 7
# 362: Add  327 City: Anito Group 7
# 363: Skip ** City:Asayita not found.
# 364: Add  328 City: Frontera Group 7
# 365: Add  329 City: Sitka Group 7
# 366: Add  330 City: Morales Group 7
# 367: Add  331 City: Borovskoy Group 7
# 368: Add  332 City: Likhoslavl Group 7
# 369: Add  333 City: Sao Goncalo Do Amarante Group 7
# 370: Add  334 City: Caravelas Group 7
# 371: Add  335 City: Salaga Group 7
# 372: Add  336 City: Andra Group 7
# 373: Add  337 City: Alice Springs Group 7
# 374: Add  338 City: Namatanai Group 7
# 375: Skip ** City:Sataua not found.
# 376: Add  339 City: Iskateley Group 7
# 377: Add  340 City: Orsk Group 7
# 378: Add  341 City: Salalah Group 7
# 379: Add  342 City: Barcelona Group 7
# 380: Add  343 City: Cabedelo Group 7
# 381: Add  344 City: Glenwood Springs Group 7
# 382: Add  345 City: Porto Novo Group 7
# 383: Add  346 City: Mehamn Group 7
# 384: Add  347 City: Guerrero Negro Group 7
# 385: Add  348 City: Faanui Group 7
# 386: Add  349 City: Oeiras Group 7
# 387: Skip ** City:Tanshui not found.
# 388: Add  350 City: Zhigansk Group 8
# 389: Add  351 City: Barrhead Group 8
# 390: Add  352 City: Tobol Group 8
# 391: Add  353 City: Kaeo Group 8
# 392: Skip ** City:Asau not found.
# 393: Add  354 City: Gangtok Group 8
# 394: Add  355 City: Kasongo Group 8
# 395: Add  356 City: Dalvik Group 8
# 396: Skip ** City:Ust-Kamchatsk not found.
# 397: Add  357 City: Shieli Group 8
# 398: Add  358 City: North Bend Group 8
# 399: Add  359 City: Aliaga Group 8
# 400: Add  360 City: Margate Group 8
# 401: Add  361 City: Ilebo Group 8
# 402: Add  362 City: Na Klang Group 8
# 403: Add  363 City: Wanaka Group 8
# 404: Add  364 City: Bubaque Group 8
# 405: Add  365 City: Rock Sound Group 8
# 406: Add  366 City: Bambous Virieux Group 8
# 407: Add  367 City: Florence Group 8
# 408: Add  368 City: Marmaris Group 8
# 409: Add  369 City: Airai Group 8
# 410: Skip ** City:Falealupo not found.
# 411: Add  370 City: Amberley Group 8
# 412: Add  371 City: Birao Group 8
# 413: Add  372 City: Yarensk Group 8
# 414: Add  373 City: Kuybyshevo Group 8
# 415: Add  374 City: Ilulissat Group 8
# 416: Add  375 City: Pervomaysk Group 8
# 417: Add  376 City: Olinda Group 8
# 418: Skip ** City:Angra not found.
# 419: Add  377 City: Kahului Group 8
# 420: Add  378 City: Kudahuvadhoo Group 8
# 421: Add  379 City: Cajnice Group 8
# 422: Add  380 City: Brae Group 8
# 423: Add  381 City: Ola Group 8
# 424: Skip ** City:Nizhneyansk not found.
# 425: Add  382 City: Muzhi Group 8
# 426: Skip ** City:Formoso Do Araguaia not found.
# 427: Skip ** City:Samusu not found.
# 428: Add  383 City: Registro Group 8
# 429: Add  384 City: Marathon Group 8
# 430: Add  385 City: Praia Da Vitoria Group 8
# 431: Add  386 City: Southbridge Group 8
# 432: Add  387 City: Ahipara Group 8
# 433: Skip ** City:Bossembele not found.
# 434: Add  388 City: Yaan Group 8
# 435: Add  389 City: Durusu Group 8
# 436: Add  390 City: Kysyl-Syr Group 8
# 437: Add  391 City: Nevelsk Group 8
# 438: Add  392 City: Zlobin Group 8
# 439: Add  393 City: Roma Group 8
# 440: Add  394 City: Nisia Floresta Group 8
# 441: Add  395 City: Kotido Group 8
# 442: Add  396 City: Tezu Group 8
# 443: Add  397 City: Labuan Group 8
# 444: Add  398 City: Aasiaat Group 8
# 445: Add  399 City: Gawler Group 8
# 446: Add  400 City: San Matias Group 9
# 447: Add  401 City: Roebourne Group 9
# 448: Add  402 City: Cururupu Group 9
# 449: Add  403 City: Alto Araguaia Group 9
# 450: Add  404 City: Saint-Francois Group 9
# 451: Add  405 City: Te Anau Group 9
# 452: Add  406 City: Ocampo Group 9
# 453: Add  407 City: Inirida Group 9
# 454: Add  408 City: Safford Group 9
# 455: Add  409 City: Coquimbo Group 9
# 456: Add  410 City: Grand Gaube Group 9
# 457: Add  411 City: Provideniya Group 9
# 458: Add  412 City: Rizhao Group 9
# 459: Add  413 City: Tianpeng Group 9
# 460: Skip ** City:Kristiinankaupunki not found.
# 461: Add  414 City: Arman Group 9
# 462: Add  415 City: Sumbe Group 9
# 463: Add  416 City: Ust-Nera Group 9
# 464: Add  417 City: Makakilo City Group 9
# 465: Add  418 City: Charlestown Group 9
# 466: Add  419 City: Tateyama Group 9
# 467: Skip ** City:Krasnoselkup not found.
# 468: Add  420 City: Ketchikan Group 9
# 469: Add  421 City: Sulangan Group 9
# 470: Add  422 City: Cabatuan Group 9
# 471: Add  423 City: Champerico Group 9
# 472: Add  424 City: Middlebury Group 9
# 473: Add  425 City: Klyuchi Group 9
# 474: Add  426 City: Manoel Urbano Group 9
# 475: Add  427 City: Kiunga Group 9
# 476: Add  428 City: Turayf Group 9
# 477: Add  429 City: Santo Tomas Group 9
# 478: Add  430 City: Siva Group 9
# 479: Add  431 City: Shubarshi Group 9
# 480: Add  432 City: Tshikapa Group 9
# 481: Add  433 City: Vao Group 9
# 482: Add  434 City: Sept-Iles Group 9
# 483: Add  435 City: Outjo Group 9
# 484: Add  436 City: Carbonia Group 9
# 485: Add  437 City: Parana Group 9
# 486: Add  438 City: Moncton Group 9
# 487: Add  439 City: Caririacu Group 9
# 488: Add  440 City: Malindi Group 9
# 489: Add  441 City: San Luis Group 9
# 490: Add  442 City: Partyzany Group 9
# 491: Add  443 City: Kupang Group 9
# 492: Add  444 City: Dunmore Town Group 9
# 493: Add  445 City: Ossora Group 9
# 494: Add  446 City: Butka Group 9
# 495: Add  447 City: Nago Group 9
# 496: Add  448 City: Assiniboia Group 9
# 497: Add  449 City: Culebra Group 9
# 498: Add  450 City: Maltahohe Group 10
# 499: Add  451 City: Songea Group 10
# 500: Add  452 City: Hanyang Group 10
# 501: Add  453 City: Agadez Group 10
# 502: Add  454 City: Skelleftea Group 10
# 503: Add  455 City: Flagstaff Group 10
# 504: Add  456 City: Opuwo Group 10
# 505: Add  457 City: Antequera Group 10
# 506: Add  458 City: Livingstonia Group 10
# 507: Add  459 City: Sarapulka Group 10
# 508: Add  460 City: Taoudenni Group 10
# 509: Add  461 City: Christchurch Group 10
# 510: Add  462 City: Serenje Group 10
# 511: Add  463 City: Fortuna Group 10
# 512: Add  464 City: Innisfail Group 10
# 513: Add  465 City: Lompoc Group 10
# 514: Add  466 City: Sawankhalok Group 10
# 515: Add  467 City: Ribeira Brava Group 10
# 516: Add  468 City: Talaya Group 10
# 517: Add  469 City: Nishihara Group 10
# 518: Skip ** City:Fianga not found.
# 519: Add  470 City: Ginir Group 10
# 520: Skip ** City:Halalo not found.
# 521: Add  471 City: Batticaloa Group 10
# 522: Add  472 City: Krasnoyarsk Group 10
# 523: Add  473 City: Sao Lourenco Do Sul Group 10
# 524: Add  474 City: Oussouye Group 10
# 525: Add  475 City: Srednekolymsk Group 10
# 526: Add  476 City: Kyaikkami Group 10
# 527: Add  477 City: Gat Group 10
# 528: Add  478 City: Vestmanna Group 10
# 529: Add  479 City: Rocha Group 10
# 530: Add  480 City: Marabba Group 10
# 531: Add  481 City: Marsaxlokk Group 10
# 532: Add  482 City: Ternate Group 10
# 533: Add  483 City: Dakar Group 10
# 534: Add  484 City: Half Moon Bay Group 10
# 535: Add  485 City: Henties Bay Group 10
# 536: Skip ** City:Doctor Pedro P. Pena not found.
# 537: Add  486 City: Bend Group 10
# 538: Add  487 City: Concepcion Group 10
# 539: Add  488 City: Vardo Group 10
# 540: Add  489 City: Oriximina Group 10
# 541: Add  490 City: Ukiah Group 10
# 542: Skip ** City:Lolua not found.
# 543: Add  491 City: Atessa Group 10
# 544: Add  492 City: Port-Gentil Group 10
# 545: Add  493 City: Tarko-Sale Group 10
# 546: Add  494 City: Walbrzych Group 10
# 547: Add  495 City: Dinar Group 10
# 548: Add  496 City: Ixtapa Group 10
# 549: Add  497 City: Oron Group 10
# 550: Add  498 City: Sidi Ali Group 10
# 551: Add  499 City: Plettenberg Bay Group 10
# 552: Add  500 City: Lasa Group 11
# 553: Add  501 City: Muscat Group 11
# 554: Skip ** City:Dzhusaly not found.
# 555: Skip ** City:Fevralsk not found.
# 556: Add  502 City: Namibe Group 11
# 557: Add  503 City: Houma Group 11
# 558: Add  504 City: Svetlaya Group 11
# 559: Skip ** City:Malakal not found.
# 560: Add  505 City: Camacupa Group 11
# 561: Skip ** City:Bargal not found.
# 562: Skip ** City:Jibuti not found.
# 563: Add  506 City: Port Hardy Group 11
# 564: Add  507 City: Flin Flon Group 11
# 565: Add  508 City: Guapi Group 11
# 566: Add  509 City: Loiza Group 11
# 567: Add  510 City: Havoysund Group 11
# 568: Skip ** City:Arrecife not found.
# 569: Add  511 City: Ludvika Group 11
# 570: Add  512 City: Mamallapuram Group 11
# 571: Add  513 City: Fort Nelson Group 11
# 572: Add  514 City: La Ronge Group 11
# 573: Add  515 City: Westport Group 11
# 574: Add  516 City: Pischia Group 11
# 575: Add  517 City: Constantine Group 11
# 576: Add  518 City: Aklavik Group 11
# 577: Add  519 City: Mantua Group 11
# 578: Add  520 City: Meadow Lake Group 11
# 579: Add  521 City: Gushikawa Group 11
# 580: Add  522 City: Ayia Trias Group 11
# 581: Add  523 City: Kungurtug Group 11
# 582: Add  524 City: Kuala Pilah Group 11
# 583: Add  525 City: Bereda Group 11
# 584: Add  526 City: Hay River Group 11
# 585: Add  527 City: Shangrao Group 11
# 586: Add  528 City: Sao Miguel Do Tapuio Group 11
# 587: Add  529 City: Boma Group 11
# 588: Add  530 City: Artigas Group 11
# 589: Skip ** City:Vaitupu not found.
# 590: Add  531 City: Tecoanapa Group 11
# 591: Add  532 City: Boshnyakovo Group 11
# 592: Add  533 City: Denpasar Group 11
# 593: Add  534 City: Tefe Group 11
# 594: Add  535 City: Thinadhoo Group 11
# 595: Add  536 City: Svarstad Group 11
# 596: Skip ** City:Moulmeingyun not found.
# 597: Add  537 City: Ustka Group 11
# 598: Add  538 City: Mishan Group 11
# 599: Add  539 City: Valdivia Group 11
# 600: Add  540 City: Lunel Group 11
# 601: Skip ** City:Mys Shmidta not found.
# 602: Add  541 City: Hobyo Group 11
# 603: Add  542 City: Villa Maria Group 11
# 604: Add  543 City: Alyangula Group 11
# 605: Add  544 City: Buta Group 11
# 606: Add  545 City: Simpang Group 11
# 607: Add  546 City: Boppard Group 11
# 608: Add  547 City: Nanortalik Group 11
# 609: Add  548 City: Vrangel Group 11
# 610: Add  549 City: Kamen-Na-Obi Group 11
# 611: Add  550 City: Verkhnevilyuysk Group 12
# 612: Add  551 City: Anloga Group 12
# 613: Add  552 City: Voskresenskoye Group 12
# 614: Add  553 City: Jalingo Group 12
# 615: Add  554 City: Sharjah Group 12
# 616: Add  555 City: Mayumba Group 12
# 617: Skip ** City:Mullaitivu not found.
# 618: Add  556 City: Sabancuy Group 12
# 619: Add  557 City: Ulundi Group 12
# 620: Add  558 City: San Quintin Group 12
# 621: Add  559 City: Hohhot Group 12
# 622: Skip ** City:Turkistan not found.
# 623: Skip ** City:Ngama not found.
# 624: Add  560 City: Shache Group 12
# 625: Add  561 City: Hami Group 12
# 626: Add  562 City: Dwarka Group 12
# 627: Add  563 City: Grindavik Group 12
# 628: Add  564 City: Port Keats Group 12
# 629: Add  565 City: Eyemouth Group 12
# 630: Add  566 City: Axim Group 12
# -----------------------------
# Data Retrieval Complete

# %% [markdown]
# ## Data Retrieval Summary

# %%
#display a nice summary for a more detailed analysis
#we could even output the combined data from above together with this summary
#to a text file
print('********SUMMARY**************')
print(f'Using {num_coordinates} coordinates, found {num_cities_found} citie(s).')
print(f'Created {modgroup} group(s) from a total of {len(weathercities)} citie(s).')
print('-----------------------------')
# Out:
# ********SUMMARY**************
# Using 1500 coordinates, found 631 citie(s).
# Created 12 group(s) from a total of 566 citie(s).
# -----------------------------

# %%
#create a workable dataframe to house api data
weather_cities_df = pd.DataFrame(weathercities)
#view the columns/data
weather_cities_df.head()
# Out:
#          analysis date        city   cityid  cloudiness country  groupingid  \
# 0  2018-09-06 06:30:05     Samarai  2132606          92      PG           1
# 1  2018-09-06 05:40:00    Acapulco  3533462          75      MX           1
# 2  2018-09-06 06:00:00       Cukai  1732945          20      MY           1
# 3  2018-09-06 05:00:00  Nouadhibou  2377457          12      MR           1
# 4  2018-09-06 06:00:00      Hobart  2163355          75      AU           1
#
#    humidity     lat   long  max temp  wind speed
# 0       100  150.67 -10.62     77.43       18.05
# 1        69  -99.88  16.86     82.40        2.24
# 2        88  103.42   4.25     78.80       10.29
# 3        45  -17.03  20.93     87.80        8.05
# 4        81  147.33 -42.88     50.00        5.82

# %%
#check for consistent values
print(weather_cities_df.count())
# Out:
# analysis date    566
# city             566
# cityid           566
# cloudiness       566
# country          566
# groupingid       566
# humidity         566
# lat              566
# long             566
# max temp         566
# wind speed       566
# dtype: int64

# %% [markdown]
# ## Data Output

# %%
#Attempt to get the date for use in charts, titles, etc...

#SOOO many issues trying to obtain a proper date formats im not even going to 
#comment on my struggle here, noted the references in its corresponding location

#get the max analysis date and use for plot titles etc.
analysisdate = weather_cities_df["analysis date"].max()

#split the date because we dont want the time
analysisdate = analysisdate.split(" ")

#get the hyphenated date for appending to file name
file_date = analysisdate[0]
print(file_date)

#use the date part of the date
analysisdate = analysisdate[0]
#https://stackoverflow.com/questions/14524322/how-to-convert-a-date-string-to-different-format
#print(analysisdate)

#format to a nicer looking string to add to titles
analysisdate = datetime.strptime(analysisdate, '%Y-%m-%d').strftime('%m/%d/%y')
print(analysisdate)
# Out:
# 2018-09-06
# 09/06/18

# %%
#append the date to the file name
fileoutput = datatofile(file_path, file_name, file_date, file_extension)
print(fileoutput)

#export the dataframe to csv
weather_cities_df.to_csv(fileoutput)
# Out:
# data/city_weather_2018-09-06.csv

# %% [markdown]
# ## Plotting Logic

# %%
#set up variables from the dataframe

#x plot lattitudes
xplot_lats = weather_cities_df["lat"]


#temperatures
yplot_temp = weather_cities_df["max temp"]

#humidities
yplot_humid = weather_cities_df["humidity"]

#cloudiness
yplot_clouds = weather_cities_df["cloudiness"]

#wind speeds
yplot_winds = weather_cities_df["wind speed"]


#used for dynamic titles..
begintitle = "City Latitude vs. "
endtitle =  " as of " + analysisdate

#leaving these empty for now so i dont lose my mind
current_title = ""
current_x_title = ""
current_y_title = ""

ymarker = "o"
x_label = "Cities"

# %% [markdown]
# ## Temperature (f) vs. Latitude

# %%
#Temperature (f) vs. Latitude

#https://matplotlib.org/api/_as_gen/matplotlib.pyplot.scatter.html
current_title = begintitle + "Temperature (f)" + endtitle
current_x_title = "Latitude"
current_y_title = "Temperature (Max) in Farenheit"

plt.figure(figsize=(10,8))

plt.scatter(xplot_lats, yplot_temp
            ,label=x_label, marker=ymarker
            ,alpha=.9
            ,c=yplot_humid,cmap="coolwarm")

plt.title(current_title)
plt.xlabel(current_x_title)
plt.ylabel(current_y_title)
plt.grid()

#save the image
image_name = "latitude_vs_temperature"
#append a number to the file name
imageoutput = datatofile(image_path, image_name, "01", image_extension)
plt.savefig(imageoutput)
#print(imageoutput)

plt.show()

# %% [markdown]
# ---
# ## Latitude vs. Humidity

# %%
#Humidity (f) vs. Latitude
current_title = begintitle + "Humidity" + endtitle
#current_x_title = "Latitude"
current_y_title = "Humidity %"

plt.figure(figsize=(10,8))

#https://stackoverflow.com/questions/17682216/scatter-plot-and-color-mapping-in-python
#https://matplotlib.org/examples/color/colormaps_reference.html
plt.scatter(xplot_lats, yplot_humid
            ,label=x_label, marker=ymarker
            ,alpha=.9
            ,c=yplot_humid,cmap="Spectral")

plt.title(current_title)
plt.xlabel(current_x_title)
plt.ylabel(current_y_title)
plt.grid()

#save the image
image_name = "latitude_vs_humidity"
#append a number to the file name
imageoutput = datatofile(image_path, image_name, "02", image_extension)
plt.savefig(imageoutput)
#print(imageoutput)

plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness

# %%
#Cloudiness vs. Latitude
current_title = begintitle + "Cloudiness" + endtitle
#current_x_title = "Latitude"
current_y_title = "Cloudiness %"

plt.figure(figsize=(10,8))

#https://stackoverflow.com/questions/17682216/scatter-plot-and-color-mapping-in-python
#https://matplotlib.org/examples/color/colormaps_reference.html
plt.scatter(xplot_lats, yplot_clouds
            ,label=x_label, marker=ymarker
            ,alpha=.9
            ,c=yplot_humid,cmap="seismic")

plt.title(current_title)
plt.xlabel(current_x_title)
plt.ylabel(current_y_title)
plt.grid()

#save the image
image_name = "latitude_vs_clouds"
#append a number to the file name
imageoutput = datatofile(image_path, image_name, "03", image_extension)
plt.savefig(imageoutput)
#print(imageoutput)

plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed

# %%
#Wind Speed vs. Latitude
current_title = begintitle + "Wind Speed" + endtitle
#current_x_title = "Latitude"
current_y_title = "Wind Speed (MPH)"

plt.figure(figsize=(10,8))

#https://stackoverflow.com/questions/17682216/scatter-plot-and-color-mapping-in-python
#https://matplotlib.org/examples/color/colormaps_reference.html
plt.scatter(xplot_lats, yplot_winds
            ,label=x_label, marker="P"
            ,alpha=.9
            ,c=yplot_humid,cmap="cool")

plt.title(current_title)
plt.xlabel(current_x_title)
plt.ylabel(current_y_title)
plt.grid()

#save the image
image_name = "latitude_vs_winds"
#append a number to the file name
imageoutput = datatofile(image_path, image_name, "04", image_extension)
plt.savefig(imageoutput)
#print(imageoutput)

plt.show()

# %% [markdown]
# ---
# ## WeatherPy - Aalvarez
