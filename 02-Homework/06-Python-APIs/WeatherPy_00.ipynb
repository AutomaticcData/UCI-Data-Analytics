# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key


# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# %% [markdown]
# ## Generate Cities List

# %%
# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)

# %%
#using the starter code, build a dataframe for lat/long visaid
#latlong_df = pd.DataFrame("Lat": lats, "Long": lngs)
latlong_df = pd.DataFrame({"Lat": lats, "Long": lngs})
latlong_df.head()
# Out:
#          Lat        Long
# 0 -66.817630 -138.709387
# 1 -57.001249 -121.324478
# 2  31.142905 -121.118754
# 3  45.646230    6.003828
# 4 -69.046761 -159.324587

# %%
lat_lngs = zip(lats, lngs)

# %%
# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        #print(city)
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 596

# %%
cities_df = pd.DataFrame({"Cities":cities})
cities_df.head()
# Out:
#           Cities
# 0        rikitea
# 1     isla vista
# 2  aix-les-bains
# 3        mataura
# 4      busselton

# %%
baseurl = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
units = "imperial"

# Build partial query URL
query_url = f"{baseurl}appid={api_key}&units={units}&q="
print(query_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=69958e30913d3cf9ab8231330ad52ba7&units=imperial&q=

# %%
#track the unique responses
responsetypes = []

#set up a counter
counter = 0

#loop through the dataframe
for index, row in cities_df.iterrows():
    #print(row["Cities"])
    thecity = row["Cities"]
    city_url = query_url + thecity
    #print(city_url)
    
    city_response = requests.get(city_url).json()
    #print(city)
    if city_response not in responsetypes:
        responsetypes.append(city_response)
    
    
    
    counter+=1

# %%
responsetypes
# Out:
# [{'coord': {'lon': -134.97, 'lat': -23.12},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 71.49,
#    'pressure': 1033.64,
#    'humidity': 100,
#    'temp_min': 71.49,
#    'temp_max': 71.49,
#    'sea_level': 1033.67,
#    'grnd_level': 1033.64},
#   'wind': {'speed': 26.53, 'deg': 94.5029},
#   'clouds': {'all': 32},
#   'dt': 1536164757,
#   'sys': {'message': 0.0035,
#    'country': 'PF',
#    'sunrise': 1536159941,
#    'sunset': 1536202266},
#   'id': 4030556,
#   'name': 'Rikitea',
#   'cod': 200},
#  {'coord': {'lon': -119.86, 'lat': 34.41},
#   'weather': [{'id': 701,
#     'main': 'Mist',
#     'description': 'mist',
#     'icon': '50d'}],
#   'base': 'stations',
#   'main': {'temp': 62.64,
#    'pressure': 1016,
#    'humidity': 87,
#    'temp_min': 59,
#    'temp_max': 66.92},
#   'visibility': 14484,
#   'wind': {'speed': 3.36, 'deg': 110},
#   'clouds': {'all': 90},
#   'dt': 1536162900,
#   'sys': {'type': 1,
#    'id': 486,
#    'message': 0.0037,
#    'country': 'US',
#    'sunrise': 1536154565,
#    'sunset': 1536200340},
#   'id': 5359864,
#   'name': 'Isla Vista',
#   'cod': 200},
#  {'coord': {'lon': 5.91, 'lat': 45.69},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 82.44,
#    'pressure': 1013,
#    'humidity': 42,
#    'temp_min': 80.6,
#    'temp_max': 84.2},
#   'visibility': 10000,
#   'wind': {'speed': 4.7, 'deg': 360},
#   'clouds': {'all': 0},
#   'dt': 1536164400,
#   'sys': {'type': 1,
#    'id': 5564,
#    'message': 0.0153,
#    'country': 'FR',
#    'sunrise': 1536123778,
#    'sunset': 1536170753},
#   'id': 3038350,
#   'name': 'Aix-les-Bains',
#   'cod': 200},
#  {'coord': {'lon': 168.86, 'lat': -46.19},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 26.4,
#    'pressure': 1025.94,
#    'humidity': 74,
#    'temp_min': 26.4,
#    'temp_max': 26.4,
#    'sea_level': 1041.69,
#    'grnd_level': 1025.94},
#   'wind': {'speed': 1.7, 'deg': 317.003},
#   'clouds': {'all': 0},
#   'dt': 1536164862,
#   'sys': {'message': 0.0049,
#    'country': 'NZ',
#    'sunrise': 1536088000,
#    'sunset': 1536128429},
#   'id': 6201424,
#   'name': 'Mataura',
#   'cod': 200},
#  {'coord': {'lon': 115.35, 'lat': -33.64},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 54.12,
#    'pressure': 1033.39,
#    'humidity': 100,
#    'temp_min': 54.12,
#    'temp_max': 54.12,
#    'sea_level': 1034.48,
#    'grnd_level': 1033.39},
#   'wind': {'speed': 7.96, 'deg': 210.003},
#   'clouds': {'all': 100},
#   'dt': 1536164862,
#   'sys': {'message': 0.0035,
#    'country': 'AU',
#    'sunrise': 1536100266,
#    'sunset': 1536141826},
#   'id': 2075265,
#   'name': 'Busselton',
#   'cod': 200},
#  {'coord': {'lon': 13.84, 'lat': -11.2},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 72.93,
#    'pressure': 1011.58,
#    'humidity': 88,
#    'temp_min': 72.93,
#    'temp_max': 72.93,
#    'sea_level': 1024.43,
#    'grnd_level': 1011.58},
#   'wind': {'speed': 7.85, 'deg': 239.003},
#   'clouds': {'all': 0},
#   'dt': 1536164818,
#   'sys': {'message': 0.0034,
#    'country': 'AO',
#    'sunrise': 1536123902,
#    'sunset': 1536166883},
#   'id': 3346015,
#   'name': 'Sumbe',
#   'cod': 200},
#  {'coord': {'lon': 1.08, 'lat': 51.28},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 64.4,
#    'pressure': 1019,
#    'humidity': 88,
#    'temp_min': 64.4,
#    'temp_max': 64.4},
#   'visibility': 10000,
#   'wind': {'speed': 11.41, 'deg': 360},
#   'clouds': {'all': 75},
#   'dt': 1536162600,
#   'sys': {'type': 1,
#    'id': 5095,
#    'message': 0.0043,
#    'country': 'GB',
#    'sunrise': 1536124547,
#    'sunset': 1536172290},
#   'id': 2653877,
#   'name': 'Canterbury',
#   'cod': 200},
#  {'coord': {'lon': 26.89, 'lat': -33.59},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 66.45,
#    'pressure': 1018.64,
#    'humidity': 83,
#    'temp_min': 66.45,
#    'temp_max': 66.45,
#    'sea_level': 1027.26,
#    'grnd_level': 1018.64},
#   'wind': {'speed': 15.12, 'deg': 223.503},
#   'clouds': {'all': 0},
#   'dt': 1536164863,
#   'sys': {'message': 0.0041,
#    'country': 'ZA',
#    'sunrise': 1536121475,
#    'sunset': 1536163068},
#   'id': 964432,
#   'name': 'Port Alfred',
#   'cod': 200},
#  {'coord': {'lon': 153.62, 'lat': -28.65},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 57.2,
#    'pressure': 1021,
#    'humidity': 93,
#    'temp_min': 57.2,
#    'temp_max': 57.2},
#   'visibility': 10000,
#   'wind': {'speed': 4.7, 'deg': 180},
#   'clouds': {'all': 90},
#   'dt': 1536163200,
#   'sys': {'type': 1,
#    'id': 8165,
#    'message': 0.0182,
#    'country': 'AU',
#    'sunrise': 1536090910,
#    'sunset': 1536132812},
#   'id': 2172880,
#   'name': 'Byron Bay',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': -73.75, 'lat': 42.65},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 82.87,
#    'pressure': 1023,
#    'humidity': 59,
#    'temp_min': 80.06,
#    'temp_max': 84.92},
#   'visibility': 16093,
#   'wind': {'speed': 6.93, 'deg': 180},
#   'clouds': {'all': 20},
#   'dt': 1536162840,
#   'sys': {'type': 1,
#    'id': 2088,
#    'message': 0.0497,
#    'country': 'US',
#    'sunrise': 1536143091,
#    'sunset': 1536189674},
#   'id': 5106834,
#   'name': 'Albany',
#   'cod': 200},
#  {'coord': {'lon': 147.33, 'lat': -42.88},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 46.4,
#    'pressure': 1016,
#    'humidity': 81,
#    'temp_min': 46.4,
#    'temp_max': 46.4},
#   'visibility': 10000,
#   'wind': {'speed': 4.7, 'deg': 70},
#   'clouds': {'all': 0},
#   'dt': 1536163200,
#   'sys': {'type': 1,
#    'id': 8195,
#    'message': 0.0042,
#    'country': 'AU',
#    'sunrise': 1536092992,
#    'sunset': 1536133764},
#   'id': 2163355,
#   'name': 'Hobart',
#   'cod': 200},
#  {'coord': {'lon': 19.24, 'lat': -34.42},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 48,
#    'pressure': 991.32,
#    'humidity': 83,
#    'temp_min': 48,
#    'temp_max': 48,
#    'sea_level': 1031.88,
#    'grnd_level': 991.32},
#   'wind': {'speed': 8.08, 'deg': 300.003},
#   'rain': {'3h': 0.3675},
#   'clouds': {'all': 88},
#   'dt': 1536164864,
#   'sys': {'message': 0.01,
#    'country': 'ZA',
#    'sunrise': 1536123341,
#    'sunset': 1536164874},
#   'id': 3366880,
#   'name': 'Hermanus',
#   'cod': 200},
#  {'coord': {'lon': -70.91, 'lat': -53.16},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 44.6,
#    'pressure': 1005,
#    'humidity': 93,
#    'temp_min': 44.6,
#    'temp_max': 44.6},
#   'visibility': 10000,
#   'wind': {'speed': 10.29, 'deg': 280},
#   'clouds': {'all': 0},
#   'dt': 1536163200,
#   'sys': {'type': 1,
#    'id': 4642,
#    'message': 0.003,
#    'country': 'CL',
#    'sunrise': 1536145882,
#    'sunset': 1536185621},
#   'id': 3874787,
#   'name': 'Punta Arenas',
#   'cod': 200},
#  {'coord': {'lon': 110.35, 'lat': 20.01},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 80.6,
#    'pressure': 1006,
#    'humidity': 94,
#    'temp_min': 80.6,
#    'temp_max': 80.6},
#   'visibility': 10000,
#   'wind': {'speed': 2.24, 'deg': 140},
#   'clouds': {'all': 0},
#   'dt': 1536159600,
#   'sys': {'type': 1,
#    'id': 7424,
#    'message': 0.0035,
#    'country': 'CN',
#    'sunrise': 1536099836,
#    'sunset': 1536144610},
#   'id': 1797535,
#   'name': 'Qiongshan',
#   'cod': 200},
#  {'coord': {'lon': -82.53, 'lat': 33.19},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 86.58,
#    'pressure': 1025,
#    'humidity': 63,
#    'temp_min': 84.2,
#    'temp_max': 89.06},
#   'visibility': 16093,
#   'wind': {'speed': 3.36, 'deg': 170},
#   'clouds': {'all': 40},
#   'dt': 1536163200,
#   'sys': {'type': 1,
#    'id': 783,
#    'message': 0.0039,
#    'country': 'US',
#    'sunrise': 1536145653,
#    'sunset': 1536191339},
#   'id': 4231997,
#   'name': 'Avera',
#   'cod': 200},
#  {'coord': {'lon': 20.04, 'lat': -34.53},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 57.2,
#    'pressure': 1016,
#    'humidity': 50,
#    'temp_min': 57.2,
#    'temp_max': 57.2},
#   'wind': {'speed': 12.75, 'deg': 350},
#   'clouds': {'all': 64},
#   'dt': 1536159600,
#   'sys': {'type': 1,
#    'id': 6591,
#    'message': 0.0037,
#    'country': 'ZA',
#    'sunrise': 1536123153,
#    'sunset': 1536164678},
#   'id': 1015776,
#   'name': 'Bredasdorp',
#   'cod': 200},
#  {'coord': {'lon': 30.79, 'lat': 59.7},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 69.8,
#    'pressure': 1020,
#    'humidity': 77,
#    'temp_min': 69.8,
#    'temp_max': 69.8},
#   'visibility': 10000,
#   'wind': {'speed': 8.95, 'deg': 150},
#   'clouds': {'all': 40},
#   'dt': 1536161400,
#   'sys': {'type': 1,
#    'id': 7267,
#    'message': 0.04,
#    'country': 'RU',
#    'sunrise': 1536116575,
#    'sunset': 1536165976},
#   'id': 546105,
#   'name': 'Nikolskoye',
#   'cod': 200},
#  {'coord': {'lon': 74.49, 'lat': 15.34},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 70.32,
#    'pressure': 959.38,
#    'humidity': 99,
#    'temp_min': 70.32,
#    'temp_max': 70.32,
#    'sea_level': 1024.43,
#    'grnd_level': 959.38},
#   'wind': {'speed': 4.72, 'deg': 262.003},
#   'rain': {'3h': 1.0825},
#   'clouds': {'all': 100},
#   'dt': 1536164866,
#   'sys': {'message': 0.0034,
#    'country': 'IN',
#    'sunrise': 1536108593,
#    'sunset': 1536153066},
#   'id': 1273574,
#   'name': 'Vaini',
#   'cod': 200},
#  {'coord': {'lon': -77.79, 'lat': 24.73},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 87.8,
#    'pressure': 1018,
#    'humidity': 62,
#    'temp_min': 87.8,
#    'temp_max': 87.8},
#   'visibility': 10000,
#   'wind': {'speed': 13.87, 'deg': 90},
#   'clouds': {'all': 40},
#   'dt': 1536163200,
#   'sys': {'type': 1,
#    'id': 4081,
#    'message': 0.0033,
#    'country': 'BS',
#    'sunrise': 1536144838,
#    'sunset': 1536189889},
#   'id': 3572906,
#   'name': 'Andros Town',
#   'cod': 200},
#  {'coord': {'lon': 161.92, 'lat': -10.46},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 81.75,
#    'pressure': 1020.1,
#    'humidity': 100,
#    'temp_min': 81.75,
#    'temp_max': 81.75,
#    'sea_level': 1022.97,
#    'grnd_level': 1020.1},
#   'wind': {'speed': 4.72, 'deg': 96.0029},
#   'clouds': {'all': 56},
#   'dt': 1536164866,
#   'sys': {'message': 0.0047,
#    'country': 'SB',
#    'sunrise': 1536088357,
#    'sunset': 1536131366},
#   'id': 2178753,
#   'name': 'Kirakira',
#   'cod': 200},
#  {'coord': {'lon': 135.83, 'lat': 46.45},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 57.45,
#    'pressure': 940.41,
#    'humidity': 99,
#    'temp_min': 57.45,
#    'temp_max': 57.45,
#    'sea_level': 1003.19,
#    'grnd_level': 940.41},
#   'wind': {'speed': 3.71, 'deg': 224.003},
#   'rain': {'3h': 1.135},
#   'clouds': {'all': 92},
#   'dt': 1536164867,
#   'sys': {'message': 0.0036,
#    'country': 'RU',
#    'sunrise': 1536092522,
#    'sunset': 1536139661},
#   'id': 2013279,
#   'name': 'Vostok',
#   'cod': 200},
#  {'coord': {'lon': 149.07, 'lat': -23.58},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 63.84,
#    'pressure': 1007.69,
#    'humidity': 73,
#    'temp_min': 63.84,
#    'temp_max': 63.84,
#    'sea_level': 1030.87,
#    'grnd_level': 1007.69},
#   'wind': {'speed': 9.75, 'deg': 71.5029},
#   'clouds': {'all': 88},
#   'dt': 1536164867,
#   'sys': {'message': 0.0134,
#    'country': 'AU',
#    'sunrise': 1536091833,
#    'sunset': 1536134068},
#   'id': 2175403,
#   'name': 'Bluff',
#   'cod': 200},
#  {'coord': {'lon': 57.66, 'lat': -20.01},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 73.4,
#    'pressure': 1025,
#    'humidity': 73,
#    'temp_min': 73.4,
#    'temp_max': 73.4},
#   'visibility': 10000,
#   'wind': {'speed': 13.87, 'deg': 110},
#   'clouds': {'all': 75},
#   'dt': 1536159600,
#   'sys': {'type': 1,
#    'id': 6729,
#    'message': 0.0032,
#    'country': 'MU',
#    'sunrise': 1536113646,
#    'sunset': 1536156118},
#   'id': 934479,
#   'name': 'Grand Gaube',
#   'cod': 200},
#  {'coord': {'lon': -61.86, 'lat': 47.38},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 66.2,
#    'pressure': 1023,
#    'humidity': 63,
#    'temp_min': 66.2,
#    'temp_max': 66.2},
#   'visibility': 32186,
#   'wind': {'speed': 6.93, 'deg': 340},
#   'clouds': {'all': 75},
#   'dt': 1536159600,
#   'sys': {'type': 1,
#    'id': 3794,
#    'message': 0.0031,
#    'country': 'CA',
#    'sunrise': 1536139949,
#    'sunset': 1536187101},
#   'id': 5915327,
#   'name': 'Cap-aux-Meules',
#   'cod': 200},
#  {'coord': {'lon': 43.97, 'lat': 26.33},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 105.8,
#    'pressure': 1007,
#    'humidity': 14,
#    'temp_min': 105.8,
#    'temp_max': 105.8},
#   'visibility': 10000,
#   'wind': {'speed': 13.87, 'deg': 360},
#   'clouds': {'all': 0},
#   'dt': 1536159600,
#   'sys': {'type': 1,
#    'id': 6984,
#    'message': 0.042,
#    'country': 'SA',
#    'sunrise': 1536115550,
#    'sunset': 1536160744},
#   'id': 107304,
#   'name': 'Buraydah',
#   'cod': 200},
#  {'coord': {'lon': 102.47, 'lat': 71.98},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 35.58,
#    'pressure': 1011.42,
#    'humidity': 87,
#    'temp_min': 35.58,
#    'temp_max': 35.58,
#    'sea_level': 1016.04,
#    'grnd_level': 1011.42},
#   'wind': {'speed': 21.72, 'deg': 300.003},
#   'clouds': {'all': 88},
#   'dt': 1536164868,
#   'sys': {'message': 0.0038,
#    'country': 'RU',
#    'sunrise': 1536096750,
#    'sunset': 1536151302},
#   'id': 2022572,
#   'name': 'Khatanga',
#   'cod': 200},
#  {'coord': {'lon': -70.2, 'lat': -22.09},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 59.88,
#    'pressure': 945.68,
#    'humidity': 94,
#    'temp_min': 59.88,
#    'temp_max': 59.88,
#    'sea_level': 1029.17,
#    'grnd_level': 945.68},
#   'wind': {'speed': 3.15, 'deg': 207.503},
#   'clouds': {'all': 0},
#   'dt': 1536164869,
#   'sys': {'message': 0.0046,
#    'country': 'CL',
#    'sunrise': 1536144376,
#    'sunset': 1536186749},
#   'id': 3869716,
#   'name': 'Tocopilla',
#   'cod': 200},
#  {'coord': {'lon': 148.03, 'lat': -34.64},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 50.07,
#    'pressure': 988.81,
#    'humidity': 78,
#    'temp_min': 50.07,
#    'temp_max': 50.07,
#    'sea_level': 1033.71,
#    'grnd_level': 988.81},
#   'wind': {'speed': 10.98, 'deg': 59.0029},
#   'clouds': {'all': 0},
#   'dt': 1536164869,
#   'sys': {'message': 0.0062,
#    'country': 'AU',
#    'sunrise': 1536092469,
#    'sunset': 1536133942},
#   'id': 2170430,
#   'name': 'Cootamundra',
#   'cod': 200},
#  {'coord': {'lon': 147.9, 'lat': 70.62},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 40.53,
#    'pressure': 1019.53,
#    'humidity': 84,
#    'temp_min': 40.53,
#    'temp_max': 40.53,
#    'sea_level': 1021.63,
#    'grnd_level': 1019.53},
#   'wind': {'speed': 12.77, 'deg': 168.503},
#   'clouds': {'all': 0},
#   'dt': 1536164870,
#   'sys': {'message': 0.0288,
#    'country': 'RU',
#    'sunrise': 1536086269,
#    'sunset': 1536140001},
#   'id': 2126123,
#   'name': 'Chokurdakh',
#   'cod': 200},
#  {'coord': {'lon': -35.15, 'lat': -8.9},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 78.69,
#    'pressure': 1019.45,
#    'humidity': 87,
#    'temp_min': 78.69,
#    'temp_max': 78.69,
#    'sea_level': 1028.03,
#    'grnd_level': 1019.45},
#   'wind': {'speed': 10.42, 'deg': 78.0029},
#   'clouds': {'all': 56},
#   'dt': 1536164776,
#   'sys': {'message': 0.0038,
#    'country': 'BR',
#    'sunrise': 1536135591,
#    'sunset': 1536178703},
#   'id': 3388456,
#   'name': 'Sao Jose da Coroa Grande',
#   'cod': 200},
#  {'coord': {'lon': -99.65, 'lat': 37.17},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 70.59,
#    'pressure': 959.54,
#    'humidity': 98,
#    'temp_min': 70.59,
#    'temp_max': 70.59,
#    'sea_level': 1031.64,
#    'grnd_level': 959.54},
#   'wind': {'speed': 5.5, 'deg': 14.0029},
#   'rain': {'3h': 0.195},
#   'clouds': {'all': 12},
#   'dt': 1536164870,
#   'sys': {'message': 0.0034,
#    'country': 'US',
#    'sunrise': 1536149589,
#    'sunset': 1536195614},
#   'id': 4267710,
#   'name': 'Sitka',
#   'cod': 200},
#  {'coord': {'lon': -69.36, 'lat': 77.48},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 33.42,
#    'pressure': 993.99,
#    'humidity': 100,
#    'temp_min': 33.42,
#    'temp_max': 33.42,
#    'sea_level': 1025.72,
#    'grnd_level': 993.99},
#   'wind': {'speed': 5.95, 'deg': 85.0029},
#   'clouds': {'all': 88},
#   'dt': 1536164870,
#   'sys': {'message': 0.0038,
#    'country': 'GL',
#    'sunrise': 1536135206,
#    'sunset': 1536195152},
#   'id': 3831208,
#   'name': 'Qaanaaq',
#   'cod': 200},
#  {'coord': {'lon': 73.1, 'lat': 6.88},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 85.17,
#    'pressure': 1026.18,
#    'humidity': 96,
#    'temp_min': 85.17,
#    'temp_max': 85.17,
#    'sea_level': 1026.13,
#    'grnd_level': 1026.18},
#   'wind': {'speed': 7.18, 'deg': 298.003},
#   'clouds': {'all': 12},
#   'dt': 1536164871,
#   'sys': {'message': 0.0035,
#    'country': 'MV',
#    'sunrise': 1536109179,
#    'sunset': 1536153154},
#   'id': 1337612,
#   'name': 'Dhidhdhoo',
#   'cod': 200},
#  {'coord': {'lon': -173.23, 'lat': 64.42},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 47.1,
#    'pressure': 1033.39,
#    'humidity': 94,
#    'temp_min': 47.1,
#    'temp_max': 47.1,
#    'sea_level': 1039.42,
#    'grnd_level': 1033.39},
#   'wind': {'speed': 8.86, 'deg': 201.003},
#   'rain': {'3h': 0.3675},
#   'clouds': {'all': 92},
#   'dt': 1536164871,
#   'sys': {'message': 0.009,
#    'country': 'RU',
#    'sunrise': 1536164948,
#    'sunset': 1536215486},
#   'id': 4031574,
#   'name': 'Provideniya',
#   'cod': 200},
#  {'coord': {'lon': 115.24, 'lat': 5.28},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 77.79,
#    'pressure': 1011,
#    'humidity': 83,
#    'temp_min': 77,
#    'temp_max': 78.8},
#   'visibility': 10000,
#   'wind': {'speed': 2.24},
#   'clouds': {'all': 75},
#   'dt': 1536163200,
#   'sys': {'type': 1,
#    'id': 8115,
#    'message': 0.0041,
#    'country': 'BN',
#    'sunrise': 1536099112,
#    'sunset': 1536143000},
#   'id': 1733782,
#   'name': 'Victoria',
#   'cod': 200},
#  {'coord': {'lon': 6.51, 'lat': 12.18},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 87.42,
#    'pressure': 966.84,
#    'humidity': 79,
#    'temp_min': 87.42,
#    'temp_max': 87.42,
#    'sea_level': 1021.31,
#    'grnd_level': 966.84},
#   'wind': {'speed': 3.83, 'deg': 293.003},
#   'clouds': {'all': 0},
#   'dt': 1536164872,
#   'sys': {'message': 0.0032,
#    'country': 'NG',
#    'sunrise': 1536125004,
#    'sunset': 1536169280},
#   'id': 2339937,
#   'name': 'Auki',
#   'cod': 200},
#  {'coord': {'lon': 114.09, 'lat': 71.97},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 36.12,
#    'pressure': 995.78,
#    'humidity': 93,
#    'temp_min': 36.12,
#    'temp_max': 36.12,
#    'sea_level': 1007.04,
#    'grnd_level': 995.78},
#   'wind': {'speed': 22.73, 'deg': 296.503},
#   'rain': {'3h': 0.22},
#   'clouds': {'all': 76},
#   'dt': 1536164872,
#   'sys': {'message': 0.0029,
#    'country': 'RU',
#    'sunrise': 1536093955,
#    'sunset': 1536148520},
#   'id': 2017155,
#   'name': 'Saskylakh',
#   'cod': 200},
#  {'coord': {'lon': -159.78, 'lat': -21.21},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 71.6,
#    'pressure': 1016,
#    'humidity': 64,
#    'temp_min': 71.6,
#    'temp_max': 71.6},
#   'visibility': 10000,
#   'wind': {'speed': 14.99, 'deg': 110},
#   'clouds': {'all': 75},
#   'dt': 1536163200,
#   'sys': {'type': 1,
#    'id': 8340,
#    'message': 0.0033,
#    'country': 'CK',
#    'sunrise': 1536165835,
#    'sunset': 1536208277},
#   'id': 4035715,
#   'name': 'Avarua',
#   'cod': 200},
#  {'coord': {'lon': -73.48, 'lat': 45.36},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 78.31,
#    'pressure': 1021,
#    'humidity': 60,
#    'temp_min': 75.2,
#    'temp_max': 83.12},
#   'visibility': 16093,
#   'wind': {'speed': 8.05, 'deg': 200},
#   'clouds': {'all': 40},
#   'dt': 1536162900,
#   'sys': {'type': 1,
#    'id': 2901,
#    'message': 0.0052,
#    'country': 'CA',
#    'sunrise': 1536142869,
#    'sunset': 1536189761},
#   'id': 6138908,
#   'name': 'Saint-Philippe',
#   'cod': 200},
#  {'coord': {'lon': 57.7, 'lat': -20.41},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 73.4,
#    'pressure': 1025,
#    'humidity': 73,
#    'temp_min': 73.4,
#    'temp_max': 73.4},
#   'visibility': 10000,
#   'wind': {'speed': 13.87, 'deg': 110},
#   'clouds': {'all': 75},
#   'dt': 1536159600,
#   'sys': {'type': 1,
#    'id': 6729,
#    'message': 0.0058,
#    'country': 'MU',
#    'sunrise': 1536113648,
#    'sunset': 1536156097},
#   'id': 934322,
#   'name': 'Mahebourg',
#   'cod': 200},
#  {'coord': {'lon': -73.76, 'lat': -42.48},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 47.28,
#    'pressure': 1002.18,
#    'humidity': 95,
#    'temp_min': 47.28,
#    'temp_max': 47.28,
#    'sea_level': 1016.89,
#    'grnd_level': 1002.18},
#   'wind': {'speed': 12.44, 'deg': 335.003},
#   'rain': {'3h': 6.62},
#   'clouds': {'all': 36},
#   'dt': 1536164735,
#   'sys': {'message': 0.0031,
#    'country': 'CL',
#    'sunrise': 1536145971,
#    'sunset': 1536186883},
#   'id': 3896218,
#   'name': 'Castro',
#   'cod': 200},
#  {'coord': {'lon': -0.6, 'lat': 45.6},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 80.6,
#    'pressure': 1014,
#    'humidity': 39,
#    'temp_min': 80.6,
#    'temp_max': 80.6},
#   'visibility': 10000,
#   'wind': {'speed': 5.82, 'deg': 10},
#   'clouds': {'all': 0},
#   'dt': 1536163200,
#   'sys': {'type': 1,
#    'id': 5528,
#    'message': 0.003,
#    'country': 'FR',
#    'sunrise': 1536125348,
#    'sunset': 1536172308},
#   'id': 3026644,
#   'name': 'Souillac',
#   'cod': 200},
#  {'coord': {'lon': 14.43, 'lat': 27.03},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 100.38,
#    'pressure': 974.7,
#    'humidity': 15,
#    'temp_min': 100.38,
#    'temp_max': 100.38,
#    'sea_level': 1024.43,
#    'grnd_level': 974.7},
#   'wind': {'speed': 7.96, 'deg': 53.5029},
#   'clouds': {'all': 0},
#   'dt': 1536164875,
#   'sys': {'message': 0.0031,
#    'country': 'LY',
#    'sunrise': 1536122616,
#    'sunset': 1536167853},
#   'id': 2212775,
#   'name': 'Sabha',
#   'cod': 200},
#  {'coord': {'lon': 26.19, 'lat': 59.1},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 64.38,
#    'pressure': 1025.29,
#    'humidity': 94,
#    'temp_min': 64.38,
#    'temp_max': 64.38,
#    'sea_level': 1032.82,
#    'grnd_level': 1025.29},
#   'wind': {'speed': 3.83, 'deg': 48.5029},
#   'rain': {'3h': 1.43},
#   'clouds': {'all': 80},
#   'dt': 1536164875,
#   'sys': {'message': 0.004,
#    'country': 'EE',
#    'sunrise': 1536117754,
#    'sunset': 1536167007},
#   'id': 588365,
#   'name': 'Vao',
#   'cod': 200},
#  {'coord': {'lon': 124.29, 'lat': 8},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 66.72,
#    'pressure': 936.2,
#    'humidity': 99,
#    'temp_min': 66.72,
#    'temp_max': 66.72,
#    'sea_level': 1023.45,
#    'grnd_level': 936.2},
#   'wind': {'speed': 2.37, 'deg': 191.003},
#   'clouds': {'all': 36},
#   'dt': 1536164875,
#   'sys': {'message': 0.0047,
#    'country': 'PH',
#    'sunrise': 1536096862,
#    'sunset': 1536140905},
#   'id': 1701054,
#   'name': 'Marawi',
#   'cod': 200},
#  {'coord': {'lon': 158.67, 'lat': 57.8},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 48.72,
#    'pressure': 1019.05,
#    'humidity': 79,
#    'temp_min': 48.72,
#    'temp_max': 48.72,
#    'sea_level': 1031.32,
#    'grnd_level': 1019.05},
#   'wind': {'speed': 6.96, 'deg': 141.503},
#   'clouds': {'all': 64},
#   'dt': 1536164876,
#   'sys': {'message': 0.0031,
#    'country': 'RU',
#    'sunrise': 1536086062,
#    'sunset': 1536135129},
#   'id': 2120612,
#   'name': 'Tigil',
#   'cod': 200},
#  {'coord': {'lon': 0.42, 'lat': 36.1},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 88.59,
#    'pressure': 1004.37,
#    'humidity': 49,
#    'temp_min': 88.59,
#    'temp_max': 88.59,
#    'sea_level': 1026.25,
#    'grnd_level': 1004.37},
#   'wind': {'speed': 5.61, 'deg': 319.503},
#   'clouds': {'all': 0},
#   'dt': 1536164876,
#   'sys': {'message': 0.0035,
#    'country': 'DZ',
#    'sunrise': 1536125608,
#    'sunset': 1536171574},
#   'id': 2487130,
#   'name': 'Sidi Ali',
#   'cod': 200},
#  {'coord': {'lon': -155.08, 'lat': 19.71},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 59.77,
#    'pressure': 1012,
#    'humidity': 87,
#    'temp_min': 48.92,
#    'temp_max': 73.04},
#   'visibility': 16093,
#   'wind': {'speed': 4.7, 'deg': 250},
#   'clouds': {'all': 20},
#   'dt': 1536162960,
#   'sys': {'type': 1,
#    'id': 818,
#    'message': 0.0032,
#    'country': 'US',
#    'sunrise': 1536163558,
#    'sunset': 1536208265},
#   'id': 5855927,
#   'name': 'Hilo',
#   'cod': 200},
#  {'coord': {'lon': -139.03, 'lat': -9.8},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 80.4,
#    'pressure': 1024.4,
#    'humidity': 97,
#    'temp_min': 80.4,
#    'temp_max': 80.4,
#    'sea_level': 1024.43,
#    'grnd_level': 1024.4},
#   'wind': {'speed': 11.77, 'deg': 75.5029},
#   'clouds': {'all': 88},
#   'dt': 1536164877,
#   'sys': {'message': 0.004,
#    'country': 'PF',
#    'sunrise': 1536160537,
#    'sunset': 1536203608},
#   'id': 4020109,
#   'name': 'Atuona',
#   'cod': 200},
#  {'coord': {'lon': 106.27, 'lat': 45.76},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 45.48,
#    'pressure': 872,
#    'humidity': 68,
#    'temp_min': 45.48,
#    'temp_max': 45.48,
#    'sea_level': 1028.76,
#    'grnd_level': 872},
#   'wind': {'speed': 25.75, 'deg': 346.003},
#   'clouds': {'all': 80},
#   'dt': 1536164877,
#   'sys': {'message': 0.0048,
#    'country': 'MN',
#    'sunrise': 1536099667,
#    'sunset': 1536146702},
#   'id': 2030065,
#   'name': 'Mandalgovi',
#   'cod': 200},
#  {'coord': {'lon': 45.34, 'lat': 2.04},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 77.52,
#    'pressure': 1027.07,
#    'humidity': 100,
#    'temp_min': 77.52,
#    'temp_max': 77.52,
#    'sea_level': 1026.94,
#    'grnd_level': 1027.07},
#   'wind': {'speed': 15.01, 'deg': 184.003},
#   'clouds': {'all': 88},
#   'dt': 1536164738,
#   'sys': {'message': 0.0045,
#    'country': 'SO',
#    'sunrise': 1536115977,
#    'sunset': 1536159681},
#   'id': 53654,
#   'name': 'Mogadishu',
#   'cod': 200},
#  {'coord': {'lon': 15.06, 'lat': -13.73},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 83.82,
#    'pressure': 851.73,
#    'humidity': 22,
#    'temp_min': 83.82,
#    'temp_max': 83.82,
#    'sea_level': 1019.4,
#    'grnd_level': 851.73},
#   'wind': {'speed': 4.61, 'deg': 36.0029},
#   'clouds': {'all': 100},
#   'dt': 1536164878,
#   'sys': {'message': 0.0036,
#    'country': 'AO',
#    'sunrise': 1536123681,
#    'sunset': 1536166521},
#   'id': 3351380,
#   'name': 'Caconda',
#   'cod': 200},
#  {'coord': {'lon': -104.67, 'lat': 23.99},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 64.4,
#    'pressure': 1026,
#    'humidity': 77,
#    'temp_min': 64.4,
#    'temp_max': 64.4},
#   'visibility': 16093,
#   'wind': {'speed': 2.24, 'deg': 140},
#   'clouds': {'all': 75},
#   'dt': 1536162300,
#   'sys': {'type': 1,
#    'id': 3983,
#    'message': 0.0058,
#    'country': 'MX',
#    'sunrise': 1536151316,
#    'sunset': 1536196311},
#   'id': 4011743,
#   'name': 'Constitucion',
#   'cod': 200},
#  {'coord': {'lon': 109.32, 'lat': 55.65},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 45.03,
#    'pressure': 908.23,
#    'humidity': 56,
#    'temp_min': 45.03,
#    'temp_max': 45.03,
#    'sea_level': 1030.22,
#    'grnd_level': 908.23},
#   'wind': {'speed': 6.96, 'deg': 322.503},
#   'clouds': {'all': 20},
#   'dt': 1536164879,
#   'sys': {'message': 0.0032,
#    'country': 'RU',
#    'sunrise': 1536098151,
#    'sunset': 1536146730},
#   'id': 2016910,
#   'name': 'Severobaykalsk',
#   'cod': 200},
#  {'coord': {'lon': 39.67, 'lat': -7.91},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 77.52,
#    'pressure': 1029.99,
#    'humidity': 100,
#    'temp_min': 77.52,
#    'temp_max': 77.52,
#    'sea_level': 1030.1,
#    'grnd_level': 1029.99},
#   'wind': {'speed': 11.43, 'deg': 121.003},
#   'clouds': {'all': 80},
#   'dt': 1536164879,
#   'sys': {'message': 0.0031,
#    'country': 'TZ',
#    'sunrise': 1536117614,
#    'sunset': 1536160774},
#   'id': 157429,
#   'name': 'Kilindoni',
#   'cod': 200},
#  {'coord': {'lon': 77.04, 'lat': 28.58},
#   'weather': [{'id': 701,
#     'main': 'Mist',
#     'description': 'mist',
#     'icon': '50n'}],
#   'base': 'stations',
#   'main': {'temp': 86,
#    'pressure': 1003,
#    'humidity': 84,
#    'temp_min': 86,
#    'temp_max': 86},
#   'visibility': 3500,
#   'wind': {'speed': 4.7, 'deg': 270},
#   'clouds': {'all': 75},
#   'dt': 1536161400,
#   'sys': {'type': 1,
#    'id': 7809,
#    'message': 0.0055,
#    'country': 'IN',
#    'sunrise': 1536107526,
#    'sunset': 1536152896},
#   'id': 1273294,
#   'name': 'Dwarka',
#   'cod': 200},
#  {'coord': {'lon': -90.35, 'lat': -0.74},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 77,
#    'pressure': 1013,
#    'humidity': 69,
#    'temp_min': 77,
#    'temp_max': 77},
#   'visibility': 10000,
#   'wind': {'speed': 16.11, 'deg': 130},
#   'clouds': {'all': 75},
#   'dt': 1536163200,
#   'sys': {'type': 1,
#    'id': 4355,
#    'message': 0.0039,
#    'country': 'EC',
#    'sunrise': 1536148612,
#    'sunset': 1536192165},
#   'id': 3652764,
#   'name': 'Puerto Ayora',
#   'cod': 200},
#  {'coord': {'lon': 54.1, 'lat': 17.01},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 77,
#    'pressure': 1008,
#    'humidity': 88,
#    'temp_min': 77,
#    'temp_max': 77},
#   'visibility': 9000,
#   'wind': {'speed': 6.93, 'deg': 170},
#   'clouds': {'all': 75},
#   'dt': 1536162600,
#   'sys': {'type': 1,
#    'id': 7115,
#    'message': 0.0046,
#    'country': 'OM',
#    'sunrise': 1536113434,
#    'sunset': 1536158008},
#   'id': 286621,
#   'name': 'Salalah',
#   'cod': 200},
#  {'coord': {'lon': 125.41, 'lat': -8.93},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 62.31,
#    'pressure': 949.01,
#    'humidity': 84,
#    'temp_min': 62.31,
#    'temp_max': 62.31,
#    'sea_level': 1026.05,
#    'grnd_level': 949.01},
#   'wind': {'speed': 1.7, 'deg': 115.503},
#   'clouds': {'all': 0},
#   'dt': 1536164880,
#   'sys': {'message': 0.0029,
#    'country': 'TL',
#    'sunrise': 1536097073,
#    'sunset': 1536140170},
#   'id': 1651810,
#   'name': 'Airai',
#   'cod': 200},
#  {'coord': {'lon': -13.05, 'lat': 20.52},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 104.16,
#    'pressure': 992.62,
#    'humidity': 27,
#    'temp_min': 104.16,
#    'temp_max': 104.16,
#    'sea_level': 1021.95,
#    'grnd_level': 992.62},
#   'wind': {'speed': 6.96, 'deg': 170.503},
#   'clouds': {'all': 0},
#   'dt': 1536164880,
#   'sys': {'message': 0.0038,
#    'country': 'MR',
#    'sunrise': 1536129439,
#    'sunset': 1536174224},
#   'id': 2381334,
#   'name': 'Atar',
#   'cod': 200},
#  {'coord': {'lon': 12.69, 'lat': 67.67},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 54.77,
#    'pressure': 1022,
#    'humidity': 93,
#    'temp_min': 51.8,
#    'temp_max': 57.2},
#   'visibility': 10000,
#   'wind': {'speed': 10.29, 'deg': 70},
#   'clouds': {'all': 0},
#   'dt': 1536162600,
#   'sys': {'type': 1,
#    'id': 5324,
#    'message': 0.0032,
#    'country': 'NO',
#    'sunrise': 1536119592,
#    'sunset': 1536171596},
#   'id': 3137469,
#   'name': 'Sorland',
#   'cod': 200},
#  {'coord': {'lon': -6.09, 'lat': 4.95},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 76.98,
#    'pressure': 1023.02,
#    'humidity': 92,
#    'temp_min': 76.98,
#    'temp_max': 76.98,
#    'sea_level': 1025.28,
#    'grnd_level': 1023.02},
#   'wind': {'speed': 8.63, 'deg': 210.003},
#   'clouds': {'all': 8},
#   'dt': 1536164881,
#   'sys': {'message': 0.0031,
#    'country': 'CI',
#    'sunrise': 1536128237,
#    'sunset': 1536172100},
#   'id': 2281951,
#   'name': 'Sassandra',
#   'cod': 200},
#  {'coord': {'lon': -1.13, 'lat': 38.18},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 86.54,
#    'pressure': 1011,
#    'humidity': 40,
#    'temp_min': 84.2,
#    'temp_max': 89.6},
#   'visibility': 10000,
#   'wind': {'speed': 13.87, 'deg': 160},
#   'clouds': {'all': 20},
#   'dt': 1536163200,
#   'sys': {'type': 1,
#    'id': 5494,
#    'message': 0.0053,
#    'country': 'ES',
#    'sunrise': 1536125882,
#    'sunset': 1536172040},
#   'id': 2517679,
#   'name': 'Fortuna',
#   'cod': 200},
#  {'coord': {'lon': -68.31, 'lat': -54.81},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 41.99,
#    'pressure': 1004,
#    'humidity': 80,
#    'temp_min': 41,
#    'temp_max': 42.8},
#   'visibility': 10000,
#   'wind': {'speed': 3.27, 'deg': 356.003},
#   'clouds': {'all': 0},
#   'dt': 1536163200,
#   'sys': {'type': 1,
#    'id': 4754,
#    'message': 0.0043,
#    'country': 'AR',
#    'sunrise': 1536145377,
#    'sunset': 1536184882},
#   'id': 3833367,
#   'name': 'Ushuaia',
#   'cod': 200},
#  {'coord': {'lon': 138.6, 'lat': -33.21},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 57.9,
#    'pressure': 963.43,
#    'humidity': 26,
#    'temp_min': 57.9,
#    'temp_max': 57.9,
#    'sea_level': 1021.75,
#    'grnd_level': 963.43},
#   'wind': {'speed': 9.86, 'deg': 352.503},
#   'clouds': {'all': 76},
#   'dt': 1536164882,
#   'sys': {'message': 0.0026,
#    'country': 'AU',
#    'sunrise': 1536094675,
#    'sunset': 1536136259},
#   'id': 2069194,
#   'name': 'Jamestown',
#   'cod': 200},
#  {'coord': {'lon': 172.79, 'lat': 3.07},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 82.92,
#    'pressure': 1021.88,
#    'humidity': 100,
#    'temp_min': 82.92,
#    'temp_max': 82.92,
#    'sea_level': 1021.87,
#    'grnd_level': 1021.88},
#   'wind': {'speed': 9.75, 'deg': 222.003},
#   'rain': {'3h': 0.775},
#   'clouds': {'all': 56},
#   'dt': 1536164882,
#   'sys': {'message': 0.0037,
#    'country': 'KI',
#    'sunrise': 1536085366,
#    'sunset': 1536129130},
#   'id': 2110227,
#   'name': 'Butaritari',
#   'cod': 200},
#  {'coord': {'lon': 84.04, 'lat': 18.42},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 77.52,
#    'pressure': 1003.72,
#    'humidity': 88,
#    'temp_min': 77.52,
#    'temp_max': 77.52,
#    'sea_level': 1016.48,
#    'grnd_level': 1003.72},
#   'wind': {'speed': 3.94, 'deg': 285.003},
#   'rain': {'3h': 0.3675},
#   'clouds': {'all': 92},
#   'dt': 1536164883,
#   'sys': {'message': 0.0032,
#    'country': 'IN',
#    'sunrise': 1536106203,
#    'sunset': 1536150870},
#   'id': 1261853,
#   'name': 'Narasannapeta',
#   'cod': 200},
#  {'coord': {'lon': -110.01, 'lat': 27.52},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 86,
#    'pressure': 1012,
#    'humidity': 62,
#    'temp_min': 86,
#    'temp_max': 86},
#   'visibility': 16093,
#   'wind': {'speed': 5.82, 'deg': 330},
#   'clouds': {'all': 40},
#   'dt': 1536162120,
#   'sys': {'type': 1,
#    'id': 3975,
#    'message': 0.0041,
#    'country': 'MX',
#    'sunrise': 1536152473,
#    'sunset': 1536197713},
#   'id': 4013704,
#   'name': 'Laguna',
#   'cod': 200},
#  {'coord': {'lon': 15.63, 'lat': 78.22},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 44.6,
#    'pressure': 1015,
#    'humidity': 70,
#    'temp_min': 44.6,
#    'temp_max': 44.6},
#   'visibility': 10000,
#   'wind': {'speed': 17.22, 'deg': 230},
#   'clouds': {'all': 75},
#   'dt': 1536162600,
#   'sys': {'type': 1,
#    'id': 5326,
#    'message': 0.0044,
#    'country': 'NO',
#    'sunrise': 1536114031,
#    'sunset': 1536175494},
#   'id': 2729907,
#   'name': 'Longyearbyen',
#   'cod': 200},
#  {'coord': {'lon': -114.38, 'lat': 62.45},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 33.8,
#    'pressure': 1022,
#    'humidity': 69,
#    'temp_min': 33.8,
#    'temp_max': 33.8},
#   'visibility': 24140,
#   'wind': {'speed': 17.22, 'deg': 350, 'gust': 12.3},
#   'clouds': {'all': 40},
#   'dt': 1536159600,
#   'sys': {'type': 1,
#    'id': 3558,
#    'message': 0.0029,
#    'country': 'CA',
#    'sunrise': 1536151105,
#    'sunset': 1536201099},
#   'id': 6185377,
#   'name': 'Yellowknife',
#   'cod': 200},
#  {'coord': {'lon': 21.7, 'lat': 36.82},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 84.2,
#    'pressure': 1010,
#    'humidity': 37,
#    'temp_min': 84.2,
#    'temp_max': 84.2},
#   'visibility': 10000,
#   'wind': {'speed': 16.11, 'deg': 320},
#   'clouds': {'all': 20},
#   'dt': 1536162600,
#   'sys': {'type': 1,
#    'id': 5680,
#    'message': 0.0032,
#    'country': 'GR',
#    'sunrise': 1536120464,
#    'sunset': 1536166504},
#   'id': 257122,
#   'name': 'Methoni',
#   'cod': 200},
#  {'coord': {'lon': -6.59, 'lat': 62.23},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 50,
#    'pressure': 1015,
#    'humidity': 100,
#    'temp_min': 50,
#    'temp_max': 50},
#   'wind': {'speed': 9.17, 'deg': 330},
#   'rain': {'3h': 1.91},
#   'clouds': {'all': 100},
#   'dt': 1536162600,
#   'sys': {'type': 1,
#    'id': 5266,
#    'message': 0.0373,
#    'country': 'FO',
#    'sunrise': 1536125220,
#    'sunset': 1536175258},
#   'id': 2618795,
#   'name': 'Klaksvik',
#   'cod': 200},
#  {'coord': {'lon': 74.49, 'lat': 65.85},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 50.88,
#    'pressure': 1031.45,
#    'humidity': 84,
#    'temp_min': 50.88,
#    'temp_max': 50.88,
#    'sea_level': 1038.53,
#    'grnd_level': 1031.45},
#   'wind': {'speed': 6.73, 'deg': 30.5029},
#   'clouds': {'all': 20},
#   'dt': 1536164885,
#   'sys': {'message': 0.0335,
#    'country': 'RU',
#    'sunrise': 1536105109,
#    'sunset': 1536156437},
#   'id': 1495626,
#   'name': 'Pangody',
#   'cod': 200},
#  {'coord': {'lon': -42.02, 'lat': -22.97},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 74.03,
#    'pressure': 1019,
#    'humidity': 60,
#    'temp_min': 73.4,
#    'temp_max': 75.2},
#   'visibility': 10000,
#   'wind': {'speed': 23.04, 'deg': 260, 'gust': 15.4},
#   'clouds': {'all': 40},
#   'dt': 1536163200,
#   'sys': {'type': 1,
#    'id': 4469,
#    'message': 0.0233,
#    'country': 'BR',
#    'sunrise': 1536137644,
#    'sunset': 1536179958},
#   'id': 3471451,
#   'name': 'Arraial do Cabo',
#   'cod': 200},
#  {'coord': {'lon': -109.91, 'lat': 22.89},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 87.8,
#    'pressure': 1014,
#    'humidity': 62,
#    'temp_min': 87.8,
#    'temp_max': 87.8},
#   'visibility': 16093,
#   'wind': {'speed': 3.36, 'deg': 60},
#   'clouds': {'all': 20},
#   'dt': 1536162180,
#   'sys': {'type': 1,
#    'id': 4016,
#    'message': 0.0045,
#    'country': 'MX',
#    'sunrise': 1536152611,
#    'sunset': 1536197532},
#   'id': 3985710,
#   'name': 'Cabo San Lucas',
#   'cod': 200},
#  {'coord': {'lon': -25.43, 'lat': 37.72},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 75.2,
#    'pressure': 1024,
#    'humidity': 69,
#    'temp_min': 75.2,
#    'temp_max': 75.2},
#   'visibility': 10000,
#   'wind': {'speed': 11.41, 'deg': 120},
#   'clouds': {'all': 20},
#   'dt': 1536163200,
#   'sys': {'type': 1,
#    'id': 5957,
#    'message': 0.0044,
#    'country': 'PT',
#    'sunrise': 1536131740,
#    'sunset': 1536177845},
#   'id': 3372472,
#   'name': 'Vila Franca do Campo',
#   'cod': 200},
#  {'coord': {'lon': 38.73, 'lat': 8.96},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 62.6,
#    'pressure': 1025,
#    'humidity': 67,
#    'temp_min': 62.6,
#    'temp_max': 62.6},
#   'visibility': 10000,
#   'wind': {'speed': 6.93, 'deg': 100},
#   'clouds': {'all': 40},
#   'dt': 1536163200,
#   'sys': {'type': 1,
#    'id': 6338,
#    'message': 0.018,
#    'country': 'ET',
#    'sunrise': 1536117366,
#    'sunset': 1536161458},
#   'id': 344979,
#   'name': 'Lebu',
#   'cod': 200},
#  {'coord': {'lon': -73.14, 'lat': -40.57},
#   'weather': [{'id': 521,
#     'main': 'Rain',
#     'description': 'shower rain',
#     'icon': '09d'}],
#   'base': 'stations',
#   'main': {'temp': 50,
#    'pressure': 1010,
#    'humidity': 76,
#    'temp_min': 50,
#    'temp_max': 50},
#   'visibility': 10000,
#   'wind': {'speed': 9.17, 'deg': 360, 'gust': 9.8},
#   'clouds': {'all': 75},
#   'dt': 1536163200,
#   'sys': {'type': 1,
#    'id': 4657,
#    'message': 0.0078,
#    'country': 'CL',
#    'sunrise': 1536145737,
#    'sunset': 1536186817},
#   'id': 3877949,
#   'name': 'Osorno',
#   'cod': 200},
#  {'coord': {'lon': 147.06, 'lat': -42.78},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 46.4,
#    'pressure': 1016,
#    'humidity': 81,
#    'temp_min': 46.4,
#    'temp_max': 46.4},
#   'visibility': 10000,
#   'wind': {'speed': 4.7, 'deg': 70},
#   'clouds': {'all': 0},
#   'dt': 1536163200,
#   'sys': {'type': 1,
#    'id': 8195,
#    'message': 0.0034,
#    'country': 'AU',
#    'sunrise': 1536093052,
#    'sunset': 1536133834},
#   'id': 2155415,
#   'name': 'New Norfolk',
#   'cod': 200},
#  {'coord': {'lon': 33.05, 'lat': -2.55},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 77,
#    'pressure': 1015,
#    'humidity': 65,
#    'temp_min': 77,
#    'temp_max': 77},
#   'visibility': 10000,
#   'wind': {'speed': 11.41, 'deg': 330},
#   'clouds': {'all': 40},
#   'dt': 1536163200,
#   'sys': {'type': 1,
#    'id': 6494,
#    'message': 0.0031,
#    'country': 'TZ',
#    'sunrise': 1536119053,
#    'sunset': 1536162507},
#   'id': 152224,
#   'name': 'Kisesa',
#   'cod': 200},
#  {'coord': {'lon': -133.03, 'lat': 69.44},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 39.2,
#    'pressure': 1021,
#    'humidity': 93,
#    'temp_min': 39.2,
#    'temp_max': 39.2},
#   'visibility': 24140,
#   'wind': {'speed': 8.05, 'deg': 220},
#   'clouds': {'all': 75},
#   'dt': 1536159600,
#   'sys': {'type': 1,
#    'id': 3555,
#    'message': 0.0037,
#    'country': 'CA',
#    'sunrise': 1536154224,
#    'sunset': 1536206877},
#   'id': 6170031,
#   'name': 'Tuktoyaktuk',
#   'cod': 200},
#  {'coord': {'lon': -94.42, 'lat': 30.04},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 85.32,
#    'pressure': 1017,
#    'humidity': 61,
#    'temp_min': 83.66,
#    'temp_max': 86},
#   'visibility': 16093,
#   'wind': {'speed': 4.7, 'deg': 360},
#   'clouds': {'all': 1},
#   'dt': 1536164100,
#   'sys': {'type': 1,
#    'id': 2561,
#    'message': 0.0052,
#    'country': 'US',
#    'sunrise': 1536148635,
#    'sunset': 1536194067},
#   'id': 4732862,
#   'name': 'Nome',
#   'cod': 200},
#  {'coord': {'lon': 73.08, 'lat': -0.6},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 81.66,
#    'pressure': 1026.5,
#    'humidity': 100,
#    'temp_min': 81.66,
#    'temp_max': 81.66,
#    'sea_level': 1026.57,
#    'grnd_level': 1026.5},
#   'wind': {'speed': 7.85, 'deg': 264.003},
#   'clouds': {'all': 24},
#   'dt': 1536164889,
#   'sys': {'message': 0.0036,
#    'country': 'MV',
#    'sunrise': 1536109395,
#    'sunset': 1536152954},
#   'id': 1282256,
#   'name': 'Hithadhoo',
#   'cod': 200},
#  {'coord': {'lon': 54.36, 'lat': 39.51},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 76.53,
#    'pressure': 987.91,
#    'humidity': 15,
#    'temp_min': 76.53,
#    'temp_max': 76.53,
#    'sea_level': 1025.93,
#    'grnd_level': 987.91},
#   'wind': {'speed': 5.95, 'deg': 73.5029},
#   'clouds': {'all': 0},
#   'dt': 1536164889,
#   'sys': {'message': 0.0035,
# ...
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 75.12,
#    'pressure': 1004.76,
#    'humidity': 93,
#    'temp_min': 75.12,
#    'temp_max': 75.12,
#    'sea_level': 1024.17,
#    'grnd_level': 1004.76},
#   'wind': {'speed': 8.08, 'deg': 254},
#   'rain': {'3h': 1.87},
#   'clouds': {'all': 80},
#   'dt': 1536165036,
#   'sys': {'message': 0.0037,
#    'country': 'NG',
#    'sunrise': 1536125065,
#    'sunset': 1536168956},
#   'id': 2337542,
#   'name': 'Naze',
#   'cod': 200},
#  {'coord': {'lon': 53.15, 'lat': 67.68},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 47.85,
#    'pressure': 1035.64,
#    'humidity': 99,
#    'temp_min': 47.85,
#    'temp_max': 47.85,
#    'sea_level': 1038.48,
#    'grnd_level': 1035.64},
#   'wind': {'speed': 16.58, 'deg': 51},
#   'rain': {'3h': 2.75},
#   'clouds': {'all': 92},
#   'dt': 1536165037,
#   'sys': {'message': 0.0033,
#    'country': 'RU',
#    'sunrise': 1536109856,
#    'sunset': 1536161916},
#   'id': 866062,
#   'name': 'Iskateley',
#   'cod': 200},
#  {'coord': {'lon': -93.08, 'lat': 43.21},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 68.58,
#    'pressure': 1021,
#    'humidity': 94,
#    'temp_min': 66.2,
#    'temp_max': 69.8},
#   'visibility': 16093,
#   'wind': {'speed': 9.17, 'deg': 10},
#   'clouds': {'all': 40},
#   'dt': 1536164100,
#   'sys': {'type': 1,
#    'id': 855,
#    'message': 0.0038,
#    'country': 'US',
#    'sunrise': 1536147702,
#    'sunset': 1536194337},
#   'id': 4866445,
#   'name': 'Rock Falls',
#   'cod': 200},
#  {'coord': {'lon': -71.34, 'lat': -29.95},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 62.6,
#    'pressure': 1018,
#    'humidity': 63,
#    'temp_min': 62.6,
#    'temp_max': 62.6},
#   'visibility': 10000,
#   'wind': {'speed': 11.41, 'deg': 270},
#   'clouds': {'all': 20},
#   'dt': 1536163200,
#   'sys': {'type': 1,
#    'id': 4666,
#    'message': 0.0036,
#    'country': 'CL',
#    'sunrise': 1536144900,
#    'sunset': 1536186779},
#   'id': 3893629,
#   'name': 'Coquimbo',
#   'cod': 200},
#  {'coord': {'lon': 35.58, 'lat': 6.99},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 64.14,
#    'pressure': 870.12,
#    'humidity': 79,
#    'temp_min': 64.14,
#    'temp_max': 64.14,
#    'sea_level': 1022.59,
#    'grnd_level': 870.12},
#   'wind': {'speed': 2.15, 'deg': 65},
#   'rain': {'3h': 0.905},
#   'clouds': {'all': 8},
#   'dt': 1536165038,
#   'sys': {'message': 0.0033,
#    'country': 'ET',
#    'sunrise': 1536118179,
#    'sunset': 1536162159},
#   'id': 330534,
#   'name': 'Mizan Teferi',
#   'cod': 200},
#  {'coord': {'lon': 21.42, 'lat': -5.35},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 75.39,
#    'pressure': 960.99,
#    'humidity': 86,
#    'temp_min': 75.39,
#    'temp_max': 75.39,
#    'sea_level': 1021.21,
#    'grnd_level': 960.99},
#   'wind': {'speed': 1.59, 'deg': 73},
#   'rain': {'3h': 0.37},
#   'clouds': {'all': 44},
#   'dt': 1536165038,
#   'sys': {'message': 0.003,
#    'country': 'CD',
#    'sunrise': 1536121921,
#    'sunset': 1536165222},
#   'id': 210939,
#   'name': 'Luebo',
#   'cod': 200},
#  {'coord': {'lon': -66.86, 'lat': -29.41},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 72.39,
#    'pressure': 966.51,
#    'humidity': 40,
#    'temp_min': 72.39,
#    'temp_max': 72.39,
#    'sea_level': 1022.76,
#    'grnd_level': 966.51},
#   'wind': {'speed': 3.71, 'deg': 156.003},
#   'clouds': {'all': 0},
#   'dt': 1536164986,
#   'sys': {'message': 0.004,
#    'country': 'AR',
#    'sunrise': 1536143808,
#    'sunset': 1536185721},
#   'id': 3848950,
#   'name': 'La Rioja',
#   'cod': 200},
#  {'coord': {'lon': 75.93, 'lat': 10.77},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 77,
#    'pressure': 1011,
#    'humidity': 83,
#    'temp_min': 77,
#    'temp_max': 77},
#   'visibility': 6000,
#   'wind': {'speed': 4.7, 'deg': 330},
#   'clouds': {'all': 40},
#   'dt': 1536163200,
#   'sys': {'type': 1,
#    'id': 7828,
#    'message': 0.0039,
#    'country': 'IN',
#    'sunrise': 1536108386,
#    'sunset': 1536152586},
#   'id': 1259411,
#   'name': 'Ponnani',
#   'cod': 200},
#  {'coord': {'lon': -74.57, 'lat': 44.94},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 85.71,
#    'pressure': 1021,
#    'humidity': 58,
#    'temp_min': 80.96,
#    'temp_max': 89.06},
#   'visibility': 16093,
#   'wind': {'speed': 11.41, 'deg': 250},
#   'clouds': {'all': 20},
#   'dt': 1536164100,
#   'sys': {'type': 1,
#    'id': 2128,
#    'message': 0.0053,
#    'country': 'US',
#    'sunrise': 1536143156,
#    'sunset': 1536189998},
#   'id': 5928065,
#   'name': 'Bombay',
#   'cod': 200},
#  {'coord': {'lon': 84.89, 'lat': 55.79},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 39.75,
#    'pressure': 1020.89,
#    'humidity': 84,
#    'temp_min': 39.75,
#    'temp_max': 39.75,
#    'sea_level': 1041.97,
#    'grnd_level': 1020.89},
#   'wind': {'speed': 3.49, 'deg': 15},
#   'clouds': {'all': 0},
#   'dt': 1536165039,
#   'sys': {'message': 0.008,
#    'country': 'RU',
#    'sunrise': 1536104008,
#    'sunset': 1536152596},
#   'id': 1485724,
#   'name': 'Talaya',
#   'cod': 200},
#  {'coord': {'lon': 172.83, 'lat': -42.52},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 34.35,
#    'pressure': 959.21,
#    'humidity': 100,
#    'temp_min': 34.35,
#    'temp_max': 34.35,
#    'sea_level': 1042.82,
#    'grnd_level': 959.21},
#   'wind': {'speed': 2.15, 'deg': 194},
#   'rain': {'3h': 0.425},
#   'clouds': {'all': 92},
#   'dt': 1536165039,
#   'sys': {'message': 0.0038,
#    'country': 'NZ',
#    'sunrise': 1536086862,
#    'sunset': 1536127657},
#   'id': 2190299,
#   'name': 'Hanmer Springs',
#   'cod': 200},
#  {'coord': {'lon': -105.25, 'lat': 19.93},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 89.52,
#    'pressure': 987.58,
#    'humidity': 59,
#    'temp_min': 89.52,
#    'temp_max': 89.52,
#    'sea_level': 1024.58,
#    'grnd_level': 987.58},
#   'wind': {'speed': 3.83, 'deg': 251},
#   'clouds': {'all': 0},
#   'dt': 1536165040,
#   'sys': {'message': 0.003,
#    'country': 'MX',
#    'sunrise': 1536151590,
#    'sunset': 1536196319},
#   'id': 3981391,
#   'name': 'Tomatlan',
#   'cod': 200},
#  {'coord': {'lon': 57.8, 'lat': 59.09},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 47.49,
#    'pressure': 1008.74,
#    'humidity': 81,
#    'temp_min': 47.49,
#    'temp_max': 47.49,
#    'sea_level': 1042.49,
#    'grnd_level': 1008.74},
#   'wind': {'speed': 2.37, 'deg': 336},
#   'clouds': {'all': 12},
#   'dt': 1536165040,
#   'sys': {'message': 0.0036,
#    'country': 'RU',
#    'sunrise': 1536110157,
#    'sunset': 1536159435},
#   'id': 496307,
#   'name': 'Severnyy-Kospashskiy',
#   'cod': 200},
#  {'coord': {'lon': 24.73, 'lat': -34},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 57.12,
#    'pressure': 1022.02,
#    'humidity': 100,
#    'temp_min': 57.12,
#    'temp_max': 57.12,
#    'sea_level': 1031.47,
#    'grnd_level': 1022.02},
#   'wind': {'speed': 18.25, 'deg': 245.5},
#   'clouds': {'all': 88},
#   'dt': 1536165040,
#   'sys': {'message': 0.0031,
#    'country': 'ZA',
#    'sunrise': 1536122008,
#    'sunset': 1536163572},
#   'id': 986717,
#   'name': 'Kruisfontein',
#   'cod': 200},
#  {'coord': {'lon': -115.98, 'lat': 36.21},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 79.11,
#    'pressure': 1019,
#    'humidity': 28,
#    'temp_min': 75.92,
#    'temp_max': 84.02},
#   'visibility': 16093,
#   'wind': {'speed': 3.15, 'deg': 141},
#   'clouds': {'all': 1},
#   'dt': 1536163080,
#   'sys': {'type': 1,
#    'id': 2059,
#    'message': 0.0038,
#    'country': 'US',
#    'sunrise': 1536153554,
#    'sunset': 1536199486},
#   'id': 5509851,
#   'name': 'Pahrump',
#   'cod': 200},
#  {'coord': {'lon': -67.4, 'lat': 46.91},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 69.98,
#    'pressure': 1022,
#    'humidity': 56,
#    'temp_min': 69.98,
#    'temp_max': 69.98},
#   'visibility': 16093,
#   'wind': {'speed': 9.17, 'deg': 150},
#   'clouds': {'all': 90},
#   'dt': 1536162960,
#   'sys': {'type': 1,
#    'id': 1351,
#    'message': 0.0044,
#    'country': 'CA',
#    'sunrise': 1536141311,
#    'sunset': 1536188398},
#   'id': 7290171,
#   'name': 'Plaster Rock',
#   'cod': 200},
#  {'coord': {'lon': 47.92, 'lat': 63.37},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 57.57,
#    'pressure': 1021.86,
#    'humidity': 77,
#    'temp_min': 57.57,
#    'temp_max': 57.57,
#    'sea_level': 1039.45,
#    'grnd_level': 1021.86},
#   'wind': {'speed': 3.94, 'deg': 249.5},
#   'clouds': {'all': 88},
#   'dt': 1536165041,
#   'sys': {'message': 0.0037,
#    'country': 'RU',
#    'sunrise': 1536111939,
#    'sunset': 1536162374},
#   'id': 576093,
#   'name': 'Blagoyevo',
#   'cod': 200},
#  {'coord': {'lon': 35.45, 'lat': 46.93},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 73.32,
#    'pressure': 1017.57,
#    'humidity': 51,
#    'temp_min': 73.32,
#    'temp_max': 73.32,
#    'sea_level': 1022.47,
#    'grnd_level': 1017.57},
#   'wind': {'speed': 7.63, 'deg': 74},
#   'clouds': {'all': 44},
#   'dt': 1536165041,
#   'sys': {'message': 0.0046,
#    'country': 'UA',
#    'sunrise': 1536116603,
#    'sunset': 1536163749},
#   'id': 701404,
#   'name': 'Tambovka',
#   'cod': 200},
#  {'coord': {'lon': 19.56, 'lat': 51.66},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 71.6,
#    'pressure': 1016,
#    'humidity': 56,
#    'temp_min': 71.6,
#    'temp_max': 71.6},
#   'visibility': 10000,
#   'wind': {'speed': 5.82, 'deg': 330},
#   'clouds': {'all': 0},
#   'dt': 1536163200,
#   'sys': {'type': 1,
#    'id': 5358,
#    'message': 0.0038,
#    'country': 'PL',
#    'sunrise': 1536120077,
#    'sunset': 1536167891},
#   'id': 3337493,
#   'name': 'Kalino',
#   'cod': 200},
#  {'coord': {'lon': 105.33, 'lat': 32.99},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 62.61,
#    'pressure': 875.96,
#    'humidity': 76,
#    'temp_min': 62.61,
#    'temp_max': 62.61,
#    'sea_level': 1022.71,
#    'grnd_level': 875.96},
#   'wind': {'speed': 3.94, 'deg': 2},
#   'clouds': {'all': 88},
#   'dt': 1536165042,
#   'sys': {'message': 0.0355,
#    'country': 'CN',
#    'sunrise': 1536100555,
#    'sunset': 1536146286},
#   'id': 7372400,
#   'name': 'Weihe',
#   'cod': 200},
#  {'coord': {'lon': 141.3, 'lat': -2.67},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 83.22,
#    'pressure': 1022.35,
#    'humidity': 100,
#    'temp_min': 83.22,
#    'temp_max': 83.22,
#    'sea_level': 1022.55,
#    'grnd_level': 1022.35},
#   'wind': {'speed': 3.15, 'deg': 330},
#   'clouds': {'all': 68},
#   'dt': 1536165042,
#   'sys': {'message': 0.0036,
#    'country': 'PG',
#    'sunrise': 1536093084,
#    'sunset': 1536136528},
#   'id': 2084442,
#   'name': 'Vanimo',
#   'cod': 200},
#  {'coord': {'lon': -3.43, 'lat': 56.4},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 62.6,
#    'pressure': 1019,
#    'humidity': 72,
#    'temp_min': 62.6,
#    'temp_max': 62.6},
#   'visibility': 10000,
#   'wind': {'speed': 9.17, 'deg': 240},
#   'clouds': {'all': 40},
#   'dt': 1536162600,
#   'sys': {'type': 1,
#    'id': 5127,
#    'message': 0.0044,
#    'country': 'GB',
#    'sunrise': 1536125172,
#    'sunset': 1536173814},
#   'id': 2640358,
#   'name': 'Perth',
#   'cod': 200},
#  {'coord': {'lon': 9.58, 'lat': 1.01},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 82.4,
#    'pressure': 1010,
#    'humidity': 74,
#    'temp_min': 82.4,
#    'temp_max': 82.4},
#   'visibility': 10000,
#   'wind': {'speed': 10.29, 'deg': 240},
#   'clouds': {'all': 20},
#   'dt': 1536163200,
#   'sys': {'type': 1,
#    'id': 6836,
#    'message': 0.0033,
#    'country': 'GA',
#    'sunrise': 1536124586,
#    'sunset': 1536168234},
#   'id': 2401357,
#   'name': 'Cocobeach',
#   'cod': 200},
#  {'coord': {'lon': -58.74, 'lat': -38.55},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 67.44,
#    'pressure': 1021.56,
#    'humidity': 59,
#    'temp_min': 67.44,
#    'temp_max': 67.44,
#    'sea_level': 1027.26,
#    'grnd_level': 1021.56},
#   'wind': {'speed': 14.23, 'deg': 338.003},
#   'clouds': {'all': 20},
#   'dt': 1536164906,
#   'sys': {'message': 0.0052,
#    'country': 'AR',
#    'sunrise': 1536142199,
#    'sunset': 1536183442},
#   'id': 3430443,
#   'name': 'Necochea',
#   'cod': 200},
#  {'coord': {'lon': 23.78, 'lat': 2.74},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 82.02,
#    'pressure': 971.78,
#    'humidity': 76,
#    'temp_min': 82.02,
#    'temp_max': 82.02,
#    'sea_level': 1020.37,
#    'grnd_level': 971.78},
#   'wind': {'speed': 3.94, 'deg': 139.503},
#   'clouds': {'all': 12},
#   'dt': 1536164760,
#   'sys': {'message': 0.0034,
#    'country': 'CD',
#    'sunrise': 1536121131,
#    'sunset': 1536164873},
#   'id': 220448,
#   'name': 'Aketi',
#   'cod': 200},
#  {'coord': {'lon': -52.21, 'lat': -3.2},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 86,
#    'pressure': 1013,
#    'humidity': 70,
#    'temp_min': 86,
#    'temp_max': 86},
#   'visibility': 10000,
#   'wind': {'speed': 3.36, 'deg': 110},
#   'clouds': {'all': 75},
#   'dt': 1536159600,
#   'sys': {'type': 1,
#    'id': 4508,
#    'message': 0.2379,
#    'country': 'BR',
#    'sunrise': 1536139528,
#    'sunset': 1536182948},
#   'id': 3407882,
#   'name': 'Altamira',
#   'cod': 200},
#  {'coord': {'lon': -17.92, 'lat': 28.66},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 77,
#    'pressure': 1018,
#    'humidity': 73,
#    'temp_min': 77,
#    'temp_max': 77},
#   'visibility': 10000,
#   'wind': {'speed': 12.75, 'deg': 30},
#   'clouds': {'all': 40},
#   'dt': 1536163200,
#   'sys': {'type': 1,
#    'id': 5515,
#    'message': 0.0036,
#    'country': 'ES',
#    'sunrise': 1536130321,
#    'sunset': 1536175671},
#   'id': 2514651,
#   'name': 'Los Llanos de Aridane',
#   'cod': 200},
#  {'coord': {'lon': 67.71, 'lat': 47.8},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 56.13,
#    'pressure': 982.96,
#    'humidity': 57,
#    'temp_min': 56.13,
#    'temp_max': 56.13,
#    'sea_level': 1031.51,
#    'grnd_level': 982.96},
#   'wind': {'speed': 14.79, 'deg': 48},
#   'clouds': {'all': 0},
#   'dt': 1536165044,
#   'sys': {'message': 0.0034,
#    'country': 'KZ',
#    'sunrise': 1536108795,
#    'sunset': 1536156074},
#   'id': 1516589,
#   'name': 'Zhezkazgan',
#   'cod': 200}]

# %%
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=69958e30913d3cf9ab8231330ad52ba7&units=imperial&q=

# %%
for city in cities:
    response = requests.get(query_url + city).json()
    print(response)



print(f"The latitude information received is: {lat}")
print(f"The temperature information received is: {temp}")

# %%
for index, row in cities_df.

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
